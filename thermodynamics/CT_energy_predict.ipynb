# %% [markdown]
# # Circuit Topology predict free energy of folding, unfolding- and folding rate

# %% [markdown]
# In this code Circuit Topology will be used to predict the free energy of folding, folding- and unfolding rate of proteins from the KPRO database. Firstly, a dataframe is prepared with kinetic information. Here the free energy of folding is calculated. Secondly, a linear regression model is built. This model takes CT parameters as input as well as contact order, for comparison. After, the model is validated using ACPRO data for the folding rate. The predicted free energy of folding is compared to the calculated predictions. Lastly, the model is used to make predictions on the MERGED database (PED and SCOPe).

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import os
import pandas as pd

from scipy import ndimage
from scipy.signal import savgol_filter
from scipy.stats import linregress
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.colors import sample_colorscale

from sklearn.metrics import r2_score
import statsmodels.api as sm
from scipy import stats
import mdtraj as md
import MDAnalysis as mda
import itertools

from sklearn.decomposition import PCA
import ast
import plotly.io as pio

# %% [markdown]
# ## Functions

# %%
#Function to calculate the contact order of a protein. 
#The contact order is a metric to define the distance between residues that form contacts with each other. 
#It is used to describe folding or compactness of a protein
# Small CO: 0.02-0.05, large CO: 0.1-0.2

def abs_contact_order3(pdb, cutoff_nm=.6):
    """Return the absolute contact order."""

    traj = md.load(pdb)
    print("Atoms: ", traj.n_atoms)
    seq_atoms = np.array([a.residue.resSeq for a in traj.top.atoms], dtype=int)
    xyz = traj.xyz[0]
    
        
    contact_count = 0
    seq_distance_sum = 0
    cutoff_2 = cutoff_nm*cutoff_nm
    N = len(seq_atoms)
    for i in range(N):
        for j in range(i+1,N):
            seq_dist = seq_atoms[j] - seq_atoms[i]
            if seq_dist > 0:
                d = 0.0
                for k in range(3):
                    d += (xyz[j,k] - xyz[i,k])**2
                if d < cutoff_2:
                    seq_distance_sum += 2*seq_dist 
                    contact_count += 2


    if contact_count==0.:
        return 0.
    print("L: ", traj.n_residues)

    return seq_distance_sum/float(contact_count), traj.n_residues


work_dir_path = r"C:\Users\akulovve\Documents\MS_student\Muriel\paper\code"

# %% [markdown]
# ## Work with K-Pro database

# %% [markdown]
# ### Make DataFrame of proteins, fragments, k_f, k_u, T, dG, Two_State

# %%
#read kon and koff data
df_kinetics = pd.read_csv(f'{work_dir_path}\KPro.tsv', sep='\t', header=0)


df_kinetics = df_kinetics[["PDB_wild","MUTATION_PDB", "MUTATED_CHAIN","T","ln(kf)_H2O","ln(ku)_H2O"]]

print("Filter 1: ", df_kinetics["PDB_wild"].unique().shape)

df_kinetics = df_kinetics.loc[df_kinetics["MUTATION_PDB"]=="WT"]

print("Filter 2: ", df_kinetics["PDB_wild"].unique().shape)

df_kinetics["T"] += 273.15
df_kinetics["K_diff"] = (df_kinetics["ln(kf)_H2O"]-df_kinetics["ln(ku)_H2O"])
df_kinetics["Energy, kcal/mol"] = 1.987204258640 * df_kinetics["T"] * df_kinetics["K_diff"] / 1000 #in R = 1.987204258640 cal/K/mol 
df_kinetics['log(Energy, kcal/mol)'] = np.log(df_kinetics['Energy, kcal/mol'])

print("Filter 3: ", df_kinetics["PDB_wild"].unique().shape)
df_kinetics.dropna(inplace=True)

print("Filter 4: ", df_kinetics["PDB_wild"].unique().shape)

df_kinetics[df_kinetics["PDB_wild"] == "1prs"]

df_kinetics.to_csv(f'{work_dir_path}\KPro_VA_v1.csv')
# Out:
# Filter 1:  (65,)
# Filter 2:  (57,)
# Filter 3:  (57,)
# Filter 4:  (54,)
# c:\Users\akulovve\Documents\MS_student\Muriel\paper\code\.conda\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning:
#
# divide by zero encountered in log

# %%
# Manually add Two_state and Fragment Start, Fragment End

# %% [markdown]
# ### Load new dataframe

# %%
df_kinetics = pd.read_csv(f'{work_dir_path}\KPro_VA_v2.csv', index_col=0)
print(df_kinetics.columns)

df_kinetics
# Out:
# Index(['PDB_wild', 'MUTATION_PDB', 'MUTATED_CHAIN', 'T', 'ln(kf)_H2O',
#        'ln(ku)_H2O', 'K_diff', 'Energy, kcal/mol', 'log(Energy, kcal/mol)',
#        'Folding Type', 'Fragment Start', 'Fragment End'],
#       dtype='object')
#     PDB_wild MUTATION_PDB MUTATED_CHAIN       T  ln(kf)_H2O  ln(ku)_H2O  \
# 0       1azu           WT             A  298.15        4.84      -16.96
# 1       1ba5           WT             A  298.15        5.91        1.16
# 2       1bdc           WT             A  310.15       11.70        4.22
# 6       1c9o           WT             A  298.15        7.22       -0.45
# 7       1coa           WT             I  298.15        4.03       -9.04
# ..       ...          ...           ...     ...         ...         ...
# 97      1AYI           WT             A  298.15        7.20        2.34
# 99      1APS           WT             A  298.15       -1.58       -9.00
# 102     1FHT           WT             A  298.15        4.62      -11.72
# 103     1UBQ           WT             A  298.15        7.33       -6.84
# 104     1L8W           WT             B  298.15        2.03       -8.47
#
#      K_diff  Energy, kcal/mol  log(Energy, kcal/mol) Folding Type  \
# 0     21.80         12.916172               2.558480          Two
# 1      4.75          2.814304               1.034715          Two
# 2      7.48          4.610159               1.528262          Two
# 6      7.67          4.544360               1.513887          Two
# 7     13.07          7.743778               2.046890          Two
# ..      ...               ...                    ...          ...
# 97     4.86          2.879477               1.057609          Two
# 99     7.42          4.396238               1.480749          Two
# 102   16.34          9.681204               2.270186          Two
# 103   14.17          8.395512               2.127697          Two
# 104   10.50          6.221092               1.827945          Two
#
#      Fragment Start  Fragment End
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 6               NaN           NaN
# 7               NaN           NaN
# ..              ...           ...
# 97              NaN           NaN
# 99              NaN           NaN
# 102             2.0         102.0
# 103             NaN           NaN
# 104             NaN           NaN
#
# [75 rows x 12 columns]

# %% [markdown]
# ### Dowload pdbs

# %%
import urllib

for pdb in df_kinetics.PDB_wild.unique():
    if not os.path.isfile('pdbs/{}.pdb'.format(pdb)):
        try:
            urllib.request.urlretrieve('https://files.rcsb.org/download/{}.pdb'.format(pdb.lower()), 'pdbs/{}.pdb'.format(pdb.lower()))
        except:
            print(f"Problems with {pdb}")

# %%
df_kinetics
# Out:
#     PDB_wild MUTATION_PDB MUTATED_CHAIN       T  ln(kf)_H2O  ln(ku)_H2O  \
# 0       1azu           WT             A  298.15        4.84      -16.96
# 1       1ba5           WT             A  298.15        5.91        1.16
# 2       1bdc           WT             A  310.15       11.70        4.22
# 6       1c9o           WT             A  298.15        7.22       -0.45
# 7       1coa           WT             I  298.15        4.03       -9.04
# ..       ...          ...           ...     ...         ...         ...
# 97      1AYI           WT             A  298.15        7.20        2.34
# 99      1APS           WT             A  298.15       -1.58       -9.00
# 102     1FHT           WT             A  298.15        4.62      -11.72
# 103     1UBQ           WT             A  298.15        7.33       -6.84
# 104     1L8W           WT             B  298.15        2.03       -8.47
#
#      K_diff  Energy, kcal/mol  log(Energy, kcal/mol) Folding Type  \
# 0     21.80         12.916172               2.558480          Two
# 1      4.75          2.814304               1.034715          Two
# 2      7.48          4.610159               1.528262          Two
# 6      7.67          4.544360               1.513887          Two
# 7     13.07          7.743778               2.046890          Two
# ..      ...               ...                    ...          ...
# 97     4.86          2.879477               1.057609          Two
# 99     7.42          4.396238               1.480749          Two
# 102   16.34          9.681204               2.270186          Two
# 103   14.17          8.395512               2.127697          Two
# 104   10.50          6.221092               1.827945          Two
#
#      Fragment Start  Fragment End
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 6               NaN           NaN
# 7               NaN           NaN
# ..              ...           ...
# 97              NaN           NaN
# 99              NaN           NaN
# 102             2.0         102.0
# 103             NaN           NaN
# 104             NaN           NaN
#
# [75 rows x 12 columns]

# %%
import os
import pandas as pd
import numpy as np

def is_hydrogen(atom_name):
    return atom_name.startswith('H')

def extract_chain_from_pdb_lines(lines, target_chain_id, frag_start=None, frag_end=None):
    """
    Extracts lines for a specific chain (excluding hydrogens) from a list of PDB lines.
    If frag_start and frag_end are provided, only extracts residues within that range.
    Returns a list of frames (each frame is a list of lines).
    """
    frames = []
    current_frame = []
    inside_model = False

    for line in lines:
        record = line[:6].strip()

        if record == 'MODEL':
            inside_model = True
            current_frame = []
        elif record == 'ENDMDL':
            inside_model = False
            frames.append(current_frame)
        elif record == 'ATOM':
            chain_id = line[21].strip()
            atom_name = line[12:16].strip()
            res_seq = int(line[22:26].strip())

            if chain_id == target_chain_id and not is_hydrogen(atom_name):
                if frag_start is not None and frag_end is not None:
                    if not (frag_start <= res_seq <= frag_end):
                        continue  # Skip residues outside fragment range

                if not inside_model:
                    current_frame = []  # Start frame on-the-fly if no MODEL/ENDMDL
                    inside_model = True

                current_frame.append(line)

        elif record in ('TER', 'END') and inside_model:
            current_frame.append(line)

    if inside_model and current_frame:
        frames.append(current_frame)

    return frames

def process_pdbs_from_dataframe_simple(input_folder, output_folder, dataframe):
    os.makedirs(output_folder, exist_ok=True)
    df = dataframe.copy()

    df['PDB_wild'] = df['PDB_wild'].str.lower().str.strip()
    df['MUTATED_CHAIN'] = df['MUTATED_CHAIN'].str.strip()

    saved_files = []  # Track intermediate files

    for _, row in df.iterrows():
        pdb_name = row['PDB_wild']
        chain_id = row['MUTATED_CHAIN']
        frag_start = row.get("Fragment Start", np.nan)
        frag_end = row.get("Fragment End", np.nan)

        # Handle NaNs
        frag_start = int(frag_start) if not pd.isna(frag_start) else None
        frag_end = int(frag_end) if not pd.isna(frag_end) else None

        pdb_file = f"{pdb_name}.pdb"
        input_path = os.path.join(input_folder, pdb_file)

        if not os.path.exists(input_path):
            print(f"File not found: {pdb_file}")
            continue

        try:
            print(f"Processing: {pdb_file}, Chain: {chain_id}, Fragment: {frag_start}-{frag_end}")

            with open(input_path, 'r') as f:
                lines = f.readlines()

            # Extract frames of the specified chain and fragment
            frames = extract_chain_from_pdb_lines(lines, chain_id, frag_start, frag_end)

            if not frames:
                print(f"  Chain {chain_id} not found or no frames extracted.")
                continue

            for i, frame_lines in enumerate(frames):
                if frag_start is not None:
                    out_name = f"{pdb_name}_chain_{chain_id}_frag_{str(frag_start)}_frame_{i+1}.pdb"
                else: 
                    out_name = f"{pdb_name}_chain_{chain_id}_frag_0_frame_{i+1}.pdb"
                out_path = os.path.join(output_folder, out_name)
                with open(out_path, 'w') as out_f:
                    out_f.writelines(frame_lines)
                print(f"  Saved: {out_name}")
                saved_files.append(out_path)

        except Exception as e:
            print(f"  Failed to process {pdb_file}: {e}")

    # # === DELETE INTERMEDIATE FILES ===
    # for file_path in saved_files:
    #     try:
    #         os.remove(file_path)
    #         print(f"Deleted: {file_path}")
    #     except Exception as e:
    #         print(f"Failed to delete {file_path}: {e}")

# === USER SETTINGS ===
input_folder = f"{work_dir_path}\pdbs"       # Change this
output_folder = f"{work_dir_path}\pdbs_proc_ProThermdDB"     # Change this
dataframe = df_kinetics[["PDB_wild", "MUTATED_CHAIN", "Fragment Start", "Fragment End"]]  # Include fragment columns

# === RUN ===
process_pdbs_from_dataframe_simple(input_folder, output_folder, dataframe)
# Out:
# Processing: 1ril.pdb, Chain: A, Fragment: None-None
#   Saved: 1ril_chain_A_frag_0_frame_1.pdb
# Processing: 2pdd.pdb, Chain: A, Fragment: 43-None
#   Saved: 2pdd_chain_A_frag_43_frame_1.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_2.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_3.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_4.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_5.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_6.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_7.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_8.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_9.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_10.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_11.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_12.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_13.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_14.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_15.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_16.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_17.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_18.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_19.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_20.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_21.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_22.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_23.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_24.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_25.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_26.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_27.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_28.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_29.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_30.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_31.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_32.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_33.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_34.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_35.pdb
# Processing: 2pdd.pdb, Chain: A, Fragment: 41-None
#   Saved: 2pdd_chain_A_frag_41_frame_1.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_2.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_3.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_4.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_5.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_6.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_7.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_8.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_9.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_10.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_11.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_12.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_13.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_14.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_15.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_16.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_17.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_18.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_19.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_20.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_21.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_22.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_23.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_24.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_25.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_26.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_27.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_28.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_29.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_30.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_31.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_32.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_33.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_34.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_35.pdb
# Processing: 2pdd.pdb, Chain: A, Fragment: 39-None
#   Saved: 2pdd_chain_A_frag_39_frame_1.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_2.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_3.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_4.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_5.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_6.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_7.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_8.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_9.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_10.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_11.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_12.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_13.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_14.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_15.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_16.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_17.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_18.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_19.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_20.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_21.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_22.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_23.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_24.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_25.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_26.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_27.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_28.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_29.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_30.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_31.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_32.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_33.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_34.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_35.pdb
# Processing: 1stn.pdb, Chain: A, Fragment: None-None
#   Saved: 1stn_chain_A_frag_0_frame_1.pdb
# Processing: 1a23.pdb, Chain: A, Fragment: None-None
#   Saved: 1a23_chain_A_frag_0_frame_1.pdb
# Processing: 1a23.pdb, Chain: A, Fragment: None-None
#   Saved: 1a23_chain_A_frag_0_frame_1.pdb
# Processing: 5azu.pdb, Chain: A, Fragment: None-None
#   Saved: 5azu_chain_A_frag_0_frame_1.pdb
# Processing: 1am7.pdb, Chain: A, Fragment: None-None
#   Saved: 1am7_chain_A_frag_0_frame_1.pdb
# Processing: 1ycc.pdb, Chain: A, Fragment: None-None
#   Saved: 1ycc_chain_A_frag_0_frame_1.pdb
# Processing: 1onc.pdb, Chain: A, Fragment: None-None
#   Saved: 1onc_chain_A_frag_0_frame_1.pdb
# Processing: 6if9.pdb, Chain: A, Fragment: 177-None
#   Saved: 6if9_chain_A_frag_177_frame_1.pdb
#   Saved: 6if9_chain_A_frag_177_frame_2.pdb
#   Saved: 6if9_chain_A_frag_177_frame_3.pdb
#   Saved: 6if9_chain_A_frag_177_frame_4.pdb
#   Saved: 6if9_chain_A_frag_177_frame_5.pdb
#   Saved: 6if9_chain_A_frag_177_frame_6.pdb
#   Saved: 6if9_chain_A_frag_177_frame_7.pdb
#   Saved: 6if9_chain_A_frag_177_frame_8.pdb
#   Saved: 6if9_chain_A_frag_177_frame_9.pdb
#   Saved: 6if9_chain_A_frag_177_frame_10.pdb
#   Saved: 6if9_chain_A_frag_177_frame_11.pdb
#   Saved: 6if9_chain_A_frag_177_frame_12.pdb
#   Saved: 6if9_chain_A_frag_177_frame_13.pdb
#   Saved: 6if9_chain_A_frag_177_frame_14.pdb
#   Saved: 6if9_chain_A_frag_177_frame_15.pdb
#   Saved: 6if9_chain_A_frag_177_frame_16.pdb
#   Saved: 6if9_chain_A_frag_177_frame_17.pdb
#   Saved: 6if9_chain_A_frag_177_frame_18.pdb
#   Saved: 6if9_chain_A_frag_177_frame_19.pdb
#   Saved: 6if9_chain_A_frag_177_frame_20.pdb
# Processing: 6if9.pdb, Chain: A, Fragment:
#   Saved: 1do9_chain_A_frag_0_frame_21.pdb
#   Saved: 1do9_chain_A_frag_0_frame_22.pdb
#   Saved: 1do9_chain_A_frag_0_frame_23.pdb
#   Saved: 1do9_chain_A_frag_0_frame_24.pdb
#   Saved: 1do9_chain_A_frag_0_frame_25.pdb
#   Saved: 1do9_chain_A_frag_0_frame_26.pdb
#   Saved: 1do9_chain_A_frag_0_frame_27.pdb
#   Saved: 1do9_chain_A_frag_0_frame_28.pdb
#   Saved: 1do9_chain_A_frag_0_frame_29.pdb
#   Saved: 1do9_chain_A_frag_0_frame_30.pdb
#   Saved: 1do9_chain_A_frag_0_frame_31.pdb
#   Saved: 1do9_chain_A_frag_0_frame_32.pdb
#   Saved: 1do9_chain_A_frag_0_frame_33.pdb
#   Saved: 1do9_chain_A_frag_0_frame_34.pdb
#   Saved: 1do9_chain_A_frag_0_frame_35.pdb
#   Saved: 1do9_chain_A_frag_0_frame_36.pdb
#   Saved: 1do9_chain_A_frag_0_frame_37.pdb
#   Saved: 1do9_chain_A_frag_0_frame_38.pdb
#   Saved: 1do9_chain_A_frag_0_frame_39.pdb
#   Saved: 1do9_chain_A_frag_0_frame_40.pdb
# Processing: 1akk.pdb, Chain: A, Fragment: None-None
#   Saved: 1akk_chain_A_frag_0_frame_1.pdb
# Processing: 1stn.pdb, Chain: A, Fragment: None-None
#   Saved: 1stn_chain_A_frag_0_frame_1.pdb
# Processing: 1hfz.pdb, Chain: A, Fragment: None-None
#   Saved: 1hfz_chain_A_frag_0_frame_1.pdb
# Processing: 1ftg.pdb, Chain: A, Fragment: None-None
#   Saved: 1ftg_chain_A_frag_0_frame_1.pdb
# Processing: 1cpm.pdb, Chain: A, Fragment: None-None
#   Saved: 1cpm_chain_A_frag_0_frame_1.pdb
# Processing: 1csp.pdb, Chain: A, Fragment: None-None
#   Saved: 1csp_chain_A_frag_0_frame_1.pdb
# Processing: 1a23.pdb, Chain: A, Fragment: None-None
#   Saved: 1a23_chain_A_frag_0_frame_1.pdb
# Processing: 1bta.pdb, Chain: A, Fragment: None-None
#   Saved: 1bta_chain_A_frag_0_frame_1.pdb
# Processing: 1cx1.pdb, Chain: A, Fragment: None-None
#   Saved: 1cx1_chain_A_frag_0_frame_1.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_2.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_3.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_4.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_5.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_6.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_7.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_8.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_9.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_10.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_11.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_12.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_13.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_14.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_15.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_16.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_17.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_18.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_19.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_20.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_21.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_22.pdb
# Processing: 1g6n.pdb, Chain: A, Fragment: None-None
#   Saved: 1g6n_chain_A_frag_0_frame_1.pdb
# Processing: 1stn.pdb, Chain: A, Fragment: None-None
#   Saved: 1stn_chain_A_frag_0_frame_1.pdb
# Processing: 1rtb.pdb, Chain: A, Fragment: None-None
#   Saved: 1rtb_chain_A_frag_0_frame_1.pdb
# Processing: 1rtp.pdb, Chain: A, Fragment: None-None
#   Chain A not found or no frames extracted.
# Processing: 1rro.pdb, Chain: A, Fragment: None-None
#   Saved: 1rro_chain_A_frag_0_frame_1.pdb
# Processing: 1tca.pdb, Chain: A, Fragment: None-None
#   Saved: 1tca_chain_A_frag_0_frame_1.pdb

# %%
CO_list_vasily = []
structure_names_list = []
pdb_list = []
L_list = []

for pdb in os.listdir('pdbs_proc_3'):
    pdb_path = "pdbs_proc_3/{}".format(pdb)
    print(pdb)
    abs_CO, L = abs_contact_order3(pdb_path)
    CO_list_vasily.append(abs_CO)

    # structure_names_list.append("{}_{}_{}".format(pdb.split("_")[0], pdb.split("_")[2], pdb.split("_")[4]))
    structure_names_list.append(pdb[:-4])
    pdb_list.append(pdb.split("_")[0])
    L_list.append(L)
# Out:
# 1aps_chain_A_frag_0_frame_1.pdb
# Atoms:  775
# L:  98
# 1aps_chain_A_frag_0_frame_2.pdb
pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_10.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_11.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_12.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_13.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_14.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_15.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_16.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_17.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_18.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_19.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_2.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_20.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_3.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_4.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_5.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_6.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_7.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_8.pdb
# Atoms:  433
# L:  54
# 2vxd_chain_A_frag_0_frame_9.pdb
# Atoms:  433
# L:  54
# 3kz3_chain_A_frag_0_frame_1.pdb
# Atoms:  618
# L:  80

# %%
df_co = pd.DataFrame({"PDB": pdb_list,"Structure name": structure_names_list, "CO": CO_list_vasily, "Length, aa": L_list, })
df_co["PDB"].unique()
df_co["CO, %"] = df_co["CO"] / df_co["Length, aa"] * 100

# %%
# Merge data frames
df_kinetics = df_kinetics.rename(columns={"PDB_wild": "PDB"})

KPro_df_VA = pd.merge(df_kinetics, df_co, on='PDB', how='inner')

# result = pd.merge(result, df, on='PDB', how='inner')
# result[['log(P)', 'log(S)', 'log(X)']] = np.log(result[['P', 'S', 'X']])

print(result.columns)
print("len: ", len(result))
# Out:
# Index(['PDB', 'MUTATION_PDB', 'MUTATED_CHAIN', 'T', 'ln(kf)_H2O', 'ln(ku)_H2O',
#        'K_diff', 'Energy, kcal/mol', 'log(Energy, kcal/mol)', 'Folding Type',
#        'Fragment Start', 'Fragment End', 'Structure name', 'CO', 'Length, aa',
#        'CO, %'],
#       dtype='object')
# len:  753

# %%
# Import PCS data and merge with "results"
df_psc = pd.read_csv(f'{work_dir_path}\PSC_VA_v1.csv', index_col=0)
df_psc = df_psc.rename(columns={"protid": "Structure name"})
df_psc = df_psc.rename(columns={"C": "X"})

df_psc.loc[:,'Structure name'] = [name[:-2] for name in df_psc["Structure name"]]

print(df_psc.columns)
KPro_df_VA = pd.merge(df_psc, KPro_df_VA, on='Structure name', how='inner')

KPro_df_VA['log(P)'] = np.log(KPro_df_VA["P"])
KPro_df_VA['log(S)'] = np.log(KPro_df_VA["S"])
KPro_df_VA['log(X)'] = np.log(KPro_df_VA["X"])

KPro_df_VA['P_normalized'] = KPro_df_VA["P"]/(KPro_df_VA["Length, aa"]**1.79*(10**(-0.41)))
KPro_df_VA["S_normalized"] = KPro_df_VA["S"]/(KPro_df_VA["Length, aa"]**2.68*(10**(-2.11)))
KPro_df_VA["X_normalized"] = KPro_df_VA["X"]/(KPro_df_VA["Length, aa"]**1.72*(10**(-0.57)))

# Count occurrences of each PDB value
pdb_counts = KPro_df_VA['PDB'].value_counts()
# Compute weights: inverse of the count
weights = 1 / pdb_counts
# Map the weights back to the DataFrame
KPro_df_VA['weights'] = KPro_df_VA['PDB'].map(weights)

KPro_df_VA.to_csv(f'{work_dir_path}\KPro_result_VA_v1.csv')

KPro_df_VA
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Import PCS data and merge with "results"
# ----> 2 df_psc = pd.read_csv(f'{work_dir_path}\PSC_VA_v1.csv', index_col=0)
#       3 df_psc = df_psc.rename(columns={"protid": "Structure name"})
#       4 df_psc = df_psc.rename(columns={"C": "X"})
#
# File c:\Users\akulovve\Documents\MS_student\Muriel\paper\code\.conda\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\akulovve\Documents\MS_student\Muriel\paper\code\.conda\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\akulovve\Documents\MS_student\Muriel\paper\code\.conda\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\akulovve\Documents\MS_student\Muriel\paper\code\.conda\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\akulovve\Documents\MS_student\Muriel\paper\code\.conda\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\akulovve\\Documents\\MS_student\\Muriel\\paper\\code\\PSC_VA_v1.csv'

# %% [markdown]
# ### Make final KPro dataframe and average all replicates

# %%
KPro_df_VA = pd.read_csv(f'{work_dir_path}\KPro_result_VA_v1.csv')
KPro_df_VA
# Out:
#      Unnamed: 0                Structure name     P     S     X      I    T_x  \
# 0             0   1azu_chain_A_frag_0_frame_1  5472  5104  2465  0.420  0.391
# 1             1   1ba5_chain_A_frag_0_frame_1   612  1857   381  0.215  0.652
# 2             2  1ba5_chain_A_frag_0_frame_10   476  1447   288  0.215  0.654
# 3             3  1ba5_chain_A_frag_0_frame_11   918  2312   511  0.245  0.618
# 4             4  1ba5_chain_A_frag_0_frame_12   865  2174   447  0.248  0.624
# ..          ...                           ...   ...   ...   ...    ...    ...
# 748         748   2vxd_chain_A_frag_0_frame_6   817  2742   446  0.204  0.685
# 749         749   2vxd_chain_A_frag_0_frame_7   652  2809   455  0.166  0.717
# 750         750   2vxd_chain_A_frag_0_frame_8   621  2758   449  0.162  0.720
# 751         751   2vxd_chain_A_frag_0_frame_9   880  2963   528  0.201  0.678
# 752         752   3kz3_chain_A_frag_0_frame_1  1191  6098   586  0.151  0.774
#
#          L   PDB MUTATION_PDB  ...         CO  Length, aa      CO, %  \
# 0    0.189  1azu           WT  ...  20.855979         126  16.552364
# 1    0.134  1ba5           WT  ...   6.077742          53  11.467438
# 2    0.130  1ba5           WT  ...   6.047486          53  11.410351
# 3    0.137  1ba5           WT  ...   6.903721          53  13.025888
# 4    0.128  1ba5           WT  ...   6.376047          53  12.030277
# ..     ...   ...          ...  ...        ...         ...        ...
# 748  0.111  2vxd           WT  ...   6.567774          54  12.162545
# 749  0.116  2vxd           WT  ...   6.354660          54  11.767890
# 750  0.117  2vxd           WT  ...   5.886302          54  10.900559
# 751  0.121  2vxd           WT  ...   6.208458          54  11.497145
# 752  0.074  3kz3           WT  ...   7.602492          80   9.503115
#
#        log(P)    log(S)    log(X)  P_normalized S_normalized  X_normalized  \
# 0    8.607399  8.537780  7.809947      2.446148     1.544961      2.234496
# 1    6.416732  7.526718  5.942799      1.289133     5.724698      1.531689
# 2    6.165418  7.277248  5.662960      1.002659     4.460764      1.157812
# 3    6.822197  7.745868  6.236370      1.933699     7.127357      2.054312
# 4    6.762730  7.684324  6.102559      1.822058     6.701935      1.797020
# ..        ...       ...       ...           ...          ...           ...
# 748  6.705639  7.916443  6.100319      1.664322     8.039928      1.736271
# 749  6.480045  7.940584  6.120297      1.328198     8.236382      1.771308
# 750  6.431331  7.922261  6.107023      1.265047     8.086843      1.747950
# 751  6.779922  7.993958  6.269096      1.792660     8.687931      2.055496
# 752  7.082549  8.715716  6.373320      1.200551     6.236002      1.160334
#
#       weights
# 0    1.000000
# 1    0.055556
# 2    0.055556
# 3    0.055556
# 4    0.055556
# ..        ...
# 748  0.050000
# 749  0.050000
# 750  0.050000
# 751  0.050000
# 752  1.000000
#
# [753 rows x 30 columns]

# %%
# 38          4.283666               1.454809   10.230000    3.000000      1.0
# 39          5.004095               1.610257    0.410000   -8.180000      1.0
# 40          5.290891               1.665987    5.020000   -3.910000      1.0
# 41          2.612859               0.960445   12.240000    7.830000      1.0
# 42          7.229297               1.971689    6.180000   -6.510000      1.0
# 43          4.070372               1.403734    6.760000   -0.110000      1.0
# 44          3.066589               1.120566    7.310000    1.860000      1.0
# 45          4.354764               1.471271    4.100000   -3.250000      1.0
# 46          4.392598               1.479921    0.840000   -6.500000      1.0
# 47          5.916781               1.777793    6.800000   -2.800000      1.0
# 48          2.780121               1.022494    2.770000   -1.970000      1.0
# 49          3.342301               1.206659    7.000000    1.060000      1.0
# 50          4.248117               1.446476   10.380000    3.210000      1.0
#
#     Length^2/3
# 0    25.133156
# 1    14.109683
# 2    15.326189
# 3    16.331621
# 4    16.000000
# 5    16.496173
# 6    17.626029
# 7    17.306995
# 8    11.103702
# 9    15.155421
# 10   22.538371
# 11   16.331621
# 12   19.483440
# 13   11.696071
# 14   14.983686
# 15   28.356413
# 16   19.634183
# 17    7.368063
# 18   17.942201
# 19   16.822843
# 20   20.965931
# 21   18.720754
# 22   19.332111
# 23   14.637223
# 24   19.483440
# 25   19.483440
# 26   23.648226
# 27   18.020809
# 28   21.111276
# 29   14.637223
# 30   16.822843
# 31   19.634183
# 32   21.973108
# 33   14.810961
# 34   15.664906
# 35   19.483440
# 36   20.082989
# 37   16.822843
# 38   12.651490
# 39   20.526834
# 40   22.397725
# 41   17.466876
# 42   19.483440
# 43   13.752451
# 44   14.637223
# 45   18.255612
# 46   20.673717
# 47   25.133156
# 48   14.637223
# 49   14.286609
# 50   18.566355

# %% [markdown]
# ### Plotings

# %% [markdown]
# #### CO

# %%
# result.plot.scatter(x = "Relative CO", y = "log(Energy, kcal/mol)")

# result.plot.scatter(x = "log(P)", y = "ln(ku)_H2O")
# fig = plt.figure(figsize=(4, 4))
# fig = px.scatter(result, x="Length, aa", y="ln(kf)_H2O", hover_name = "PDB", width=800, height=400)
# fig.show()

fig = px.scatter(KPro_df_VA, x="CO", y="ln(kf)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="CO", y="ln(ku)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="CO", y="Energy, kcal/mol", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

# %% [markdown]
# #### CT parameters

# %%
fig = make_subplots(rows=3, cols=3)

fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(P)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 1, col = 1)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(S)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 2, col = 1)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(X)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 3, col = 1)


fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(P)"], y=KPro_df_VA_avg["ln(kf)_H2O"],mode="markers"), row = 1, col = 2)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(S)"], y=KPro_df_VA_avg["ln(kf)_H2O"],mode="markers"), row = 2, col = 2)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(X)"], y=KPro_df_VA_avg["ln(kf)_H2O"],mode="markers"), row = 3, col = 2)

fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(P)"], y=KPro_df_VA_avg["ln(ku)_H2O"],mode="markers"), row = 1, col = 3)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(S)"], y=KPro_df_VA_avg["ln(ku)_H2O"],mode="markers"), row = 2, col = 3)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(X)"], y=KPro_df_VA_avg["ln(ku)_H2O"],mode="markers"), row = 3, col = 3)


fig.update_layout(height=800, width=800,)
fig.show()

# %% [markdown]
# #### CT from length

# %%
fig = px.scatter(KPro_df_VA, x="Length, aa", y="P", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3, log_x=True, log_y=True)

a = np.linspace(10,160,5)
b = a**1.79 * (10**(-0.41))
fig.add_scatter(x=a, y=b)
fig.show()


fig = px.scatter(KPro_df_VA, x="Length, aa", y="S", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3, log_x=True, log_y=True)

a = np.linspace(10,160,5)
b = a**2.68 * (10**(-2.11))
fig.add_scatter(x=a, y=b)
fig.show()


fig = px.scatter(KPro_df_VA, x="Length, aa", y="X", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3, log_x=True, log_y=True)

a = np.linspace(10,160,5)
b = a**1.72 * (10**(-0.57))
fig.add_scatter(x=a, y=b)
fig.show()



# KPro_df_VA['P_normalized'] = KPro_df_VA["P"]/(KPro_df_VA["Length, aa"]**1.79*(10**(-0.41)))
# KPro_df_VA["S_normalized"] = KPro_df_VA["S"]/(KPro_df_VA["Length, aa"]**2.68*(10**(-2.11)))
# KPro_df_VA["X_normalized"] = KPro_df_VA["X"]/(KPro_df_VA["Length, aa"]**1.72*(10**(-0.57)))

# %% [markdown]
# #### Normalized CT

# %%
fig = px.scatter(KPro_df_VA, x="Length, aa", y="P_normalized", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="Length, aa", y="S_normalized", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="Length, aa", y="X_normalized", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

# %% [markdown]
# #### Length as predictor

# %%
fig = px.scatter(KPro_df_VA, x="Length, aa", y="ln(kf)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="Length, aa", y="ln(ku)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="Length, aa", y="Energy, kcal/mol", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

# %% [markdown]
# #### CT devide on lenght

# %%
KPro_df_VA['log(P)/L'] = KPro_df_VA["P"]/KPro_df_VA["Length, aa"]
KPro_df_VA['log(S)/L'] = KPro_df_VA["S"]/KPro_df_VA["Length, aa"]
KPro_df_VA['log(X)/L'] = KPro_df_VA["X"]/KPro_df_VA["Length, aa"]


fig = px.scatter(KPro_df_VA, x="X_normalized", y="ln(kf)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="X_normalized", y="ln(ku)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(KPro_df_VA, x="X_normalized", y="Energy, kcal/mol", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

# %% [markdown]
# #### 3D plots, logCT

# %%
fig = px.scatter_3d(KPro_df_VA, 
                    x='log(P)', y='log(S)', z='log(X)',
                    color='ln(ku)_H2O',
                    hover_name = "PDB",
                    width=800, height=400,
                    )
fig.update_traces(marker_size = 3)
fig.show()

# %% [markdown]
# #### Energy predictions by CO, CT  and length

# %%
fig = px.scatter(KPro_df_VA, x="log(S)", y="ln(kf)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

fig = px.scatter(KPro_df_VA, x="CO", y="ln(kf)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

fig = px.scatter(KPro_df_VA, x="Length, aa", y="ln(kf)_H2O", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

# %% [markdown]
# ## Linear regression model

# %%
from sklearn.metrics import mean_squared_error
from scipy import stats

def evaluate_model(train, test, feature_columns, target_column, model_name):

    coefficients = []
    intercepts = []
    coefficient_errors = []
    intercept_errors = []
    

    X_train = train[feature_columns]
    y_train = train[target_column]

    X_test = test[feature_columns]
    y_test = test[target_column]
    
    

    X_train = sm.add_constant(X_train)
    X_test = sm.add_constant(X_test)
    
    # model = sm.WLS(y_train, X_train, weights=weights_train).fit()
    model = sm.OLS(y_train, X_train, ).fit()
    # print(model.params)

    intercepts.append(model.params['const'])
    coefficients.append(model.params.iloc[1:].values)
    coefficient_errors.append(model.bse.iloc[1:].values)
    intercept_errors.append(model.bse.iloc[0])

    avg_coefficients = np.mean(coefficients, axis=0)
    avg_intercept = np.mean(intercepts)
    avg_coefficient_errors = np.mean(coefficient_errors, axis=0)
    avg_intercept_error = np.mean(intercept_errors)
    
    formatted_coefficients = [round(coef, 3) for coef in avg_coefficients]
    formatted_coefficient_errors = [round(err, 3) for err in avg_coefficient_errors]
    
    MSE_train = mean_squared_error(y_train, model.predict(X_train))
    rpearson_train, pvalue_train = stats.pearsonr(y_train, model.predict(X_train))

    MSE_test = mean_squared_error(y_test, model.predict(X_test))
    rpearson_test, pvalue_test = stats.pearsonr(y_test, model.predict(X_test))
    
    result = {
        "Model": model_name,
        "Feature Columns": ", ".join(feature_columns),
        "Target Column": target_column,

        "Coefficients": formatted_coefficients,
        "Coefficient Errors": formatted_coefficient_errors,
        "Intercept": round(avg_intercept, 3),
        "Intercept Error": round(avg_intercept_error, 3),

        "MSE train": round(MSE_train, 3),
        "MSE test": round(MSE_test, 3),

        "R train": round(rpearson_train, 3),
        "R test": round(rpearson_test, 3),

        "p-value train": round(pvalue_train, 3),
        "p-value test": round(pvalue_test, 3),

    }
    return result


models = [
    {"model_name": "length_energy", "features": ['Length, aa'], "target": 'Energy, kcal/mol'},
    {"model_name": "CO_energy", "features": ['CO'], "target": 'Energy, kcal/mol'},
    {"model_name": "logCT_logEnergy", "features": ['log(P)', 'log(S)', 'log(X)'], "target": 'log(Energy, kcal/mol)'},

    {"model_name": "length_logkf", "features": ['Length, aa'], "target": 'ln(kf)_H2O'},
    {"model_name": "CO_logkf", "features": ['CO'], "target": 'ln(kf)_H2O'},
    {"model_name": "logCT_logkf", "features": ['log(P)', 'log(S)', 'log(X)'], "target": 'ln(kf)_H2O'},

    {"model_name": "length_logku", "features": ['Length, aa'], "target": 'ln(ku)_H2O'},
    {"model_name": "CO_logku", "features": ['CO'], "target": 'ln(ku)_H2O'},
    {"model_name": "logCT_logku", "features": ['log(P)', 'log(S)', 'log(X)'], "target": 'ln(ku)_H2O'},
]

results = []

#split data frame on test and train proteins structures
unique_proteins = KPro_df_VA_avg["PDB"].unique()
train_proteins, test_proteins = train_test_split(unique_proteins, test_size=0.5, random_state=3724761)
train = KPro_df_VA_avg[KPro_df_VA_avg["PDB"].isin(train_proteins)]
test = KPro_df_VA_avg[KPro_df_VA_avg["PDB"].isin(test_proteins)]


#train the models
for model in models:
    print(model)
    result = evaluate_model(train,test,
                            feature_columns = model["features"],
                            target_column = model["target"],
                            model_name = model["model_name"])
    results.append(result)

KPro_regression_VA = pd.DataFrame(results)
KPro_regression_VA['params'] = KPro_regression_VA.apply(lambda row: row['Coefficients'] + [row['Intercept']], axis=1)
KPro_regression_VA['name_list'] = [
                'Length, aa vs Energy',
                'Contact Order  vs Energy',
                'Log P, S, X vs logEnergy',

                'Length, aa vs log folding rate',
                'Contact Order vs log folding rate',
                'Log P, S, X vs log folding rate',
                
                'Length, aa vs log unfolding rate',
                'Contact Order  vs log unfolding rate',
                'Log P, S, X vs log unfolding rate',
]
KPro_regression_VA
# Out:
# {'model_name': 'length_energy', 'features': ['Length, aa'], 'target': 'Energy, kcal/mol'}
# {'model_name': 'CO_energy', 'features': ['CO'], 'target': 'Energy, kcal/mol'}
# {'model_name': 'logCT_logEnergy', 'features': ['log(P)', 'log(S)', 'log(X)'], 'target': 'log(Energy, kcal/mol)'}
# {'model_name': 'length_logkf', 'features': ['Length, aa'], 'target': 'ln(kf)_H2O'}
# {'model_name': 'CO_logkf', 'features': ['CO'], 'target': 'ln(kf)_H2O'}
# {'model_name': 'logCT_logkf', 'features': ['log(P)', 'log(S)', 'log(X)'], 'target': 'ln(kf)_H2O'}
# {'model_name': 'length_logku', 'features': ['Length, aa'], 'target': 'ln(ku)_H2O'}
# {'model_name': 'CO_logku', 'features': ['CO'], 'target': 'ln(ku)_H2O'}
# {'model_name': 'logCT_logku', 'features': ['log(P)', 'log(S)', 'log(X)'], 'target': 'ln(ku)_H2O'}
#              Model         Feature Columns          Target Column  \
# 0    length_energy              Length, aa       Energy, kcal/mol
# 1        CO_energy                      CO       Energy, kcal/mol
# 2  logCT_logEnergy  log(P), log(S), log(X)  log(Energy, kcal/mol)
# 3     length_logkf              Length, aa             ln(kf)_H2O
# 4         CO_logkf                      CO             ln(kf)_H2O
# 5      logCT_logkf  log(P), log(S), log(X)             ln(kf)_H2O
# 6     length_logku              Length, aa             ln(ku)_H2O
# 7         CO_logku                      CO             ln(ku)_H2O
# 8      logCT_logku  log(P), log(S), log(X)             ln(ku)_H2O
#
#               Coefficients     Coefficient Errors  Intercept  Intercept Error  \
# 0                  [0.083]                [0.017]     -1.475            1.381
# 1                  [0.399]                [0.097]      0.498            1.142
# 2    [0.342, 0.089, 0.139]  [0.324, 0.124, 0.408]     -2.604            0.703
# 3                 [-0.056]                [0.026]      9.926            2.057
# 4                  [-0.45]                [0.115]     10.576            1.346
# 5   [-2.752, 1.722, -0.72]  [2.151, 0.825, 2.712]     16.835            4.676
# 6                 [-0.197]                [0.035]     12.375            2.773
# 7                  [-1.12]                [0.156]      9.610            1.835
# 8  [-4.128, 2.137, -3.662]  [3.195, 1.224, 4.027]     34.068            6.944
#
#    MSE train  MSE test  R train  R test  p-value train  p-value test  \
# 0      3.390     2.109    0.706   0.762          0.000         0.000
# 1      3.903     3.195    0.650   0.553          0.000         0.003
# 2      0.128     0.105    0.784   0.742          0.000         0.000
# 3      7.524    12.824    0.411   0.346          0.041         0.083
# 4      5.426     7.924    0.633   0.719          0.001         0.000
# 5      5.678     7.497    0.611   0.766          0.001         0.000
# 6     13.670    15.812    0.762   0.720          0.000         0.000
# 7     10.084     8.847    0.831   0.857          0.000         0.000
# 8     12.519    10.017    0.785   0.865          0.000         0.000
#
#                             params                             name_list
# 0                  [0.083, -1.475]                  Length, aa vs Energy
# 1                   [0.399, 0.498]              Contact Order  vs Energy
# 2    [0.342, 0.089, 0.139, -2.604]              Log P, S, X vs logEnergy
# 3                  [-0.056, 9.926]        Length, aa vs log folding rate
# 4                  [-0.45, 10.576]     Contact Order vs log folding rate
# 5   [-2.752, 1.722, -0.72, 16.835]       Log P, S, X vs log folding rate
# 6                 [-0.197, 12.375]      Length, aa vs log unfolding rate
# 7                    [-1.12, 9.61]  Contact Order  vs log unfolding rate
# 8  [-4.128, 2.137, -3.662, 34.068]     Log P, S, X vs log unfolding rate

# %% [markdown]
# The weights of the model are calculated: 1/ error*number of samples(structures)

# %% [markdown]
# ### Predict dG and prepare df

# %%
def pred_dG(spx_vec, param):
    dG = np.dot(spx_vec, param[:-1]) + param[-1]
    return dG

data = {
    "y_measured_energy": test['Energy, kcal/mol'],
    "y_measured_log10kf": test['ln(kf)_H2O'],
    "y_measured_log10ku": test['ln(ku)_H2O'],

    "y_pred_length_energy": (pred_dG(test[['Length, aa']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="length_energy",'params'].values[0]))),
    "y_pred_CO_energy": (pred_dG(test[['CO']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="CO_energy","params"].values[0]))),
    "y_pred_logCT_logEnergy": np.exp(pred_dG(test[['log(P)', 'log(S)', 'log(X)']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="logCT_logEnergy","params"].values[0]))),

    "y_pred_length_logkf": pred_dG(test[['Length, aa']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="length_logkf","params"].values[0])),
    "y_pred_CO_logkf": pred_dG(test[['CO']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="CO_logkf","params"].values[0])),
    "y_pred_logCT_logkf": pred_dG(test[['log(P)', 'log(S)', 'log(X)']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="logCT_logkf","params"].values[0])),

    "y_pred_length_logku": pred_dG(test[['Length, aa']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="length_logku","params"].values[0])),
    "y_pred_CO_logku": pred_dG(test[['CO']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="CO_logku","params"].values[0])),
    "y_pred_logCT_logku": pred_dG(test[['log(P)', 'log(S)', 'log(X)']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="logCT_logku","params"].values[0])),
}

#Take the mean of values for structures of a protein
df_lineair_regression = pd.DataFrame(data)
df_lineair_regression['PDB'] = test['PDB']
df_lineair_regression
# Out:
#     y_measured_energy  y_measured_log10kf  y_measured_log10ku  \
# 2            4.610159           11.700000            4.220000
# 6            4.830727            5.526667           -2.626667
# 7            4.079407            4.520000           -2.730000
# 8            2.374496           10.050000            5.830000
# 10           5.640457            1.240000           -8.280000
# 11           6.138144            6.340000           -4.020000
# 13           1.007224            8.400000            6.700000
# 14           3.074997            2.470000           -2.720000
# 15          11.547532            7.440000          -12.050000
# 16           4.170181           -0.940000           -8.050000
# 18           3.341615            3.980000           -1.660000
# 19           2.281067            5.290000            1.440000
# 21           4.319215            6.715000           -0.575000
# 23           4.751729            6.300000           -1.720000
# 25           5.714805            0.500000           -9.310000
# 26           6.283763           -0.360000          -11.110000
# 27           6.472898            8.040000           -2.885000
# 33           3.464062            1.626667           -4.220000
# 34           4.893926           11.480000            3.220000
# 38           4.283666           10.230000            3.000000
# 41           2.612859           12.240000            7.830000
# 42           7.229297            6.180000           -6.510000
# 46           4.392598            0.840000           -6.500000
# 47           5.916781            6.800000           -2.800000
# 49           3.342301            7.000000            1.060000
# 50           4.248117           10.380000            3.210000
#
#     y_pred_length_energy  y_pred_CO_energy  y_pred_logCT_logEnergy  \
# 2                 3.5050          2.660045                3.137639
# 6                 4.6670          4.462202                3.637805
# 7                 4.5010          4.745461                3.894656
# 8                 1.5960          2.927049                1.691429
# 10                7.4060          8.047712                7.963526
# 11                4.0030          5.104522                4.310192
# 13                1.8450          3.353306                2.163726
# 14                3.3390          5.000959                3.984129
# 15               11.0580          8.127617                9.802235
# 16                5.7460          6.847555                5.093954
# 18                4.8330          6.036925                4.346669
# 19                4.2520          4.893064                3.557580
# 21                5.2480          5.103715                4.449391
# 23                3.1730          4.366421                3.829374
# 25                5.6630          5.816098                4.462916
# 26                8.0700          6.744511                9.392155
# 27                4.8745          5.491042                5.317370
# 33                3.2560          4.842706                4.056052
# 34                3.6710          2.923549                3.894250
# 38                2.2600          3.058451                2.691843
# 41                4.5840          3.275855                2.893529
# 42                5.6630          5.397553                7.467639
# 46                6.3270          8.285791                8.279587
# 47                8.9830          6.660436                8.924058
# 49                3.0070          2.956054                3.211333
# 50                5.1650          3.531394                4.392163
#
#     y_pred_length_logkf  y_pred_CO_logkf  y_pred_logCT_logkf  \
# 2                 6.566         8.137603            7.904003
# 6                 5.782         6.105095            6.927989
# 7                 5.894         5.785630            5.283467
# 8                 7.854         7.836472            6.802959
# 10                3.934         2.061287            2.607375
# 11                6.230         5.380674            4.796885
# 13                7.686         7.355730            5.656144
# 14                6.678         5.497475            4.201065
# 15                1.470         1.971169            3.006242
# 16                5.054         3.414848            2.514439
# 18                5.670         4.329092            4.025221
# 19                6.062         5.619161            5.482880
# 21                5.390         5.381584            4.881550
# 23                6.790         6.213119            5.619406
# 25                5.110         4.578145            5.158733
# 26                3.486         3.531063            3.156257
# 27                5.642         4.944749            4.270275
# 33                6.734         5.675956            3.867804
# 34                6.454         7.840418            7.031525
# 38                7.406         7.688274            7.207974
# 41                5.838         7.443081            9.004660
# 42                5.110         5.050188            4.331191
# 46                4.662         1.792777            1.442228
# 47                2.870         3.625884            3.297232
# 49                6.902         7.803759            8.226853
# 50                5.446         7.154879            7.763499
#
#     y_pred_length_logku  y_pred_CO_logku  y_pred_logCT_logku   PDB
# 2                0.5550         3.541100            1.887715  1bdc
# 6               -2.2030        -1.517585           -0.225061  1div
# 7               -1.8090        -2.312698           -2.402265  1dkt
# 8                5.0860         2.791618            4.245147  1e0l
# 10              -8.7040       -11.582175          -10.281415  1fkb
# 11              -0.6270        -3.320589           -4.614439  1g6p
# 13               4.4950         1.595106            1.055329  1jmq
# 14               0.9490        -3.029885           -3.834295  1jo8
# 15             -17.3720       -11.806469          -10.969561  1k0s
# 16              -4.7640        -8.213313           -7.530676  1k8m
# 18              -2.5970        -5.937860           -5.104185  1m9s
# 19              -1.2180        -2.727022           -1.979367  1mjc
# 21              -3.5820        -3.318323           -3.171008  1o6x
# 23               1.3430        -1.248726           -2.596943  1pgb
# 25              -4.5670        -5.317995           -4.207713  1prs
# 26             -10.2800        -7.924065          -11.155811  1qtu
# 27              -2.6955        -4.405557           -5.706877  1rfa
# 33               1.1460        -2.585665           -4.667651  1shg
# 34               0.1610         2.801441           -0.526350  1ss1
# 38               3.5100         2.422770            1.289948  1w4e
# 41              -2.0060         1.812513            4.201834  2a3d
# 42              -4.5670        -4.143132           -7.061639  2abd
# 46              -6.1430       -12.250466          -13.148368  2vh7
# 47             -12.4470        -7.688066          -10.393526  2vik
# 49               1.7370         2.710199            1.899501  2vxd
# 50              -3.3850         1.095209            0.117628  3kz3

# %%
def pred_dG(spx_vec, param):
    dG = np.dot(spx_vec, param[:-1]) + param[-1]
    return dG

data = {
    "y_measured_energy": train['Energy, kcal/mol'],
    "y_measured_log10kf": train['ln(kf)_H2O'],
    "y_measured_log10ku": train['ln(ku)_H2O'],

    "y_pred_length_energy": (pred_dG(train[['Length, aa']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="length_energy",'params'].values[0]))),
    "y_pred_CO_energy": (pred_dG(train[['CO']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="CO_energy","params"].values[0]))),
    "y_pred_logCT_logEnergy": np.exp(pred_dG(train[['log(P)', 'log(S)', 'log(X)']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="logCT_logEnergy","params"].values[0]))),

    "y_pred_length_logkf": pred_dG(train[['Length, aa']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="length_logkf","params"].values[0])),
    "y_pred_CO_logkf": pred_dG(train[['CO']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="CO_logkf","params"].values[0])),
    "y_pred_logCT_logkf": pred_dG(train[['log(P)', 'log(S)', 'log(X)']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="logCT_logkf","params"].values[0])),

    "y_pred_length_logku": pred_dG(train[['Length, aa']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="length_logku","params"].values[0])),
    "y_pred_CO_logku": pred_dG(train[['CO']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="CO_logku","params"].values[0])),
    "y_pred_logCT_logku": pred_dG(train[['log(P)', 'log(S)', 'log(X)']], param = np.array(KPro_regression_VA.loc[KPro_regression_VA["Model"]=="logCT_logku","params"].values[0])),
}

#Take the mean of values for structures of a protein
df_lineair_regression = pd.DataFrame(data)
df_lineair_regression['PDB'] = train['PDB']
std_df = df_lineair_regression.groupby('PDB').std().add_suffix('_std')
df_lineair_regression = df_lineair_regression.merge(std_df, on='PDB', how='left')
df_lineair_regr = df_lineair_regression.groupby("PDB").mean()
df_lineair_regression
# Out:
#     y_measured_energy  y_measured_log10kf  y_measured_log10ku  \
# 0           12.916172                4.84             -16.960
# 1            2.814304                5.91               1.160
# 2            4.544360                7.22              -0.450
# 3            8.635468                4.89              -9.685
# 4            2.381789                6.32               2.300
# 5            3.460112                8.73               2.890
# 6            5.963636                7.21              -3.145
# 7            0.629706               12.39              11.320
# 8            3.495661                2.02              -3.880
# 9            5.167209                2.70              -6.170
# 10           3.652582               -1.04              -7.310
# 11           8.543633                5.83              -8.590
# 12           3.335690                4.36              -1.270
# 13           2.719506                9.08               4.490
# 14           2.988476                7.78               2.650
# 15           7.240166                8.74              -3.480
# 16           8.269003                8.52              -6.440
# 17           6.701005                1.69              -9.620
# 18           3.601132                7.70               1.300
# 19           5.004095                0.41              -8.180
# 20           5.290891                5.02              -3.910
# 21           4.070372                6.76              -0.110
# 22           3.066589                7.31               1.860
# 23           4.354764                4.10              -3.250
# 24           2.780121                2.77              -1.970
#
#     y_pred_length_energy  y_pred_CO_energy  y_pred_logCT_logEnergy  \
# 0                  8.983          8.819535                8.892210
# 1                  2.924          3.019341                3.120869
# 2                  4.003          4.948449                3.590593
# 3                  3.837          4.446114                3.592569
# 4                  4.086          4.880845                3.297072
# 5                  3.422          2.944952                3.018966
# 6                  5.663          4.640839                6.030047
# 7                  0.185          2.047026                0.892072
# 8                  6.493          5.915547                6.104705
# 9                  5.580          6.476527                5.764743
# 10                 5.663          6.077436                3.720771
# 11                 6.576          7.832860                6.796405
# 12                 3.173          5.031991                2.805019
# 13                 4.252          3.707217                4.978560
# 14                 5.746          3.514974                5.290454
# 15                 7.074          5.227429                6.119865
# 16                 5.663          4.663597                5.376463
# 17                 5.995          6.653392                4.963561
# 18                 4.252          3.925541                4.890901
# 19                 6.244          8.039194                7.862491
# 20                 7.323          3.484385                4.547989
# 21                 2.758          3.339584                2.676662
# 22                 3.173          2.730408                3.118738
# 23                 4.999          4.416751                3.604846
# 24                 3.173          4.879424                3.590755
#
#     y_pred_length_logkf  y_pred_CO_logkf  y_pred_logCT_logkf  \
# 0                 2.870         1.190810            2.226332
# 1                 6.958         7.732382            7.553392
# 2                 6.230         5.556697            5.519203
# 3                 6.342         6.123240            5.876051
# 4                 6.174         5.632942            5.671624
# 5                 6.622         7.816280            8.228053
# 6                 5.110         5.903625            5.249989
# 7                 8.806         8.828978            8.561256
# 8                 4.550         4.465984            4.592121
# 9                 5.166         3.833300            4.299917
# 10                5.110         4.283403            4.838996
# 11                4.494         2.303602            3.026969
# 12                6.790         5.462477            4.772202
# 13                6.062         6.956582            6.013200
# 19                      NaN                  NaN                     NaN
# 20                      NaN                  NaN                     NaN
# 21                      NaN                  NaN                     NaN
# 22                      NaN                  NaN                     NaN
# 23                      NaN                  NaN                     NaN
# 24                      NaN                  NaN                     NaN
#
#     y_pred_length_logku_std  y_pred_CO_logku_std  y_pred_logCT_logku_std
# 0                       NaN                  NaN                     NaN
# 1                       NaN                  NaN                     NaN
# 2                       NaN                  NaN                     NaN
# 3                       NaN                  NaN                     NaN
# 4                       NaN                  NaN                     NaN
# 5                       NaN                  NaN                     NaN
# 6                       NaN                  NaN                     NaN
# 7                       NaN                  NaN                     NaN
# 8                       NaN                  NaN                     NaN
# 9                       NaN                  NaN                     NaN
# 10                      NaN                  NaN                     NaN
# 11                      NaN                  NaN                     NaN
# 12                      NaN                  NaN                     NaN
# 13                      NaN                  NaN                     NaN
# 14                      NaN                  NaN                     NaN
# 15                      NaN                  NaN                     NaN
# 16                      NaN                  NaN                     NaN
# 17                      NaN                  NaN                     NaN
# 18                      NaN                  NaN                     NaN
# 19                      NaN                  NaN                     NaN
# 20                      NaN                  NaN                     NaN
# 21                      NaN                  NaN                     NaN
# 22                      NaN                  NaN                     NaN
# 23                      NaN                  NaN                     NaN
# 24                      NaN                  NaN                     NaN
#
# [25 rows x 25 columns]

# %% [markdown]
# Use block below to save dataframe

# %%
# df_lineair_regr.to_csv('/CT_analysis/Dataframes/KPRO_pred_df_v0')

# %% [markdown]
# Load in dataframe

# %%
# df_lineair_regr = pd.read_csv('/CT_analysis/Dataframes/KPRO_pred_df_v0', index_col=0)

# %% [markdown]
# ### Plot free energy of folding predictions

# %% [markdown]
# #### Energy Plot

# %%
# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_energy', 'y_pred_CO_energy','y_pred_logCT_logEnergy']
color_list = ['Length, aa','Contact Order','CT parameters',]
colors = ['blue', 'red', 'green']

experimental_data = 'y_measured_energy'


axis_min = np.min(df_lineair_regression[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression[predicted_list+[experimental_data]])) // 1 )

axis_range = [axis_min, axis_max]

fig = go.Figure()

for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression[experimental_data], df_lineair_regression[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression[experimental_data],
        y= df_lineair_regression[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=10, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        # error_x=dict(
        #     type='data',
        #     array=error_x_values,
        #     visible=True,
        #     thickness=1.5,
        #     width=8,
        #     color=color
        # )
    ))

    x_range = np.linspace(axis_range[0],axis_range[1], 20)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
    ))

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression[experimental_data], df_lineair_regression[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression[experimental_data], df_lineair_regression[model_data])

    #number of symbols in sign
    n_s = len(f"R=0.00 p-value=0.00 MSE=0.00 ")
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / n_s),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"p-value={pvalue:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 + n_s3 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False
))


#Plot tytle
fig.update_layout(
    title_text=" Predicted free energy",
    title_x=0.5,
    title_font=dict(size=32),
    width=1150,
    height=750,
    showlegend=True,
    plot_bgcolor="white",
    font=dict(family="Arial", size=32, color='black'),
    margin=dict(l=200, r=100, t=80, b=100)
)

#Set axis names and ranges
fig.update_xaxes(
    title_text="∆𝐺<sub>exp</sub>(kcal/mol)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=32),
    tickfont=dict(size=32),
    showline=True,
    linecolor="black",
    mirror=True,
)

fig.update_yaxes(
    title_text="∆𝐺<sub>pred</sub>(kcal/mol)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=32),
    tickfont=dict(size=32),
    showline=True,
    linecolor="black",
    mirror=True,
)

fig.write_image(f'{work_dir_path}/images/models_energy_v0.png', scale=1)
fig.show()

# %% [markdown]
# #### Folding Rate Plot

# %%
from sklearn.metrics import mean_squared_error
from scipy import stats


# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_logkf', 'y_pred_CO_logkf','y_pred_logCT_logkf']
color_list = ['Length, aa', 'Contact Order','CT parameters']
colors = ['blue', 'red', 'green']

experimental_data = 'y_measured_log10kf'

axis_min = np.min(df_lineair_regression[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression[predicted_list+[experimental_data]])) // 1 )
axis_range = [axis_min, axis_max]

fig = go.Figure()

for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression[experimental_data], df_lineair_regression[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression[experimental_data],
        y= df_lineair_regression[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=10, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        # error_x=dict(
        #     type='data',
        #     array=error_x_values,
        #     visible=True,
        #     thickness=1.5,
        #     width=8,
        #     color=color
        # )
    ))

    x_range = np.linspace(axis_range[0],axis_range[1], 2)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
    ))

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression[experimental_data], df_lineair_regression[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression[experimental_data], df_lineair_regression[model_data])

    #number of symbols in sign
    n_s = len(f"R=0.00 p-value=0.00 MSE=0.00 ")
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / n_s),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"p-value={pvalue:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 + n_s3 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )
    
#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False
))


#Plot tytle
fig.update_layout(
    title_text=" Predicted Folding Rate",
    title_x=0.5,
    title_font=dict(size=32),
    width=1150,
    height=750,
    showlegend=True,
    plot_bgcolor="white",
    font=dict(family="Arial", size=32, color='black'),
    margin=dict(l=200, r=100, t=80, b=100)
)

#Set axis names and ranges
fig.update_xaxes(
    title_text="ln k<sub>f,exp</sub> (s<sup>−1</sup>)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=32),
    tickfont=dict(size=32),
    showline=True,
    linecolor="black",
    mirror=True,
)

fig.update_yaxes(
    title_text="ln k<sub>f,pred</sub> (s<sup>−1</sup>)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=32),
    tickfont=dict(size=32),
    showline=True,
    linecolor="black",
    mirror=True,
)


fig.write_image(f'{work_dir_path}/images/models_logkf_v0.png', scale=5)

fig.show()

# %% [markdown]
# #### Unfolding rate plot

# %%
from sklearn.metrics import mean_squared_error
from scipy import stats


# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_logku', 'y_pred_CO_logku','y_pred_logCT_logku']
color_list = ['Length, aa', 'Contact Order','CT parameters']
colors = ['blue', 'red', 'green']

experimental_data = 'y_measured_log10ku'

axis_min = np.min(df_lineair_regression[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression[predicted_list+[experimental_data]])) // 1 )
axis_range = [axis_min, axis_max]

fig = go.Figure()

for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression[experimental_data], df_lineair_regression[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression[experimental_data],
        y= df_lineair_regression[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=10, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        # error_x=dict(
        #     type='data',
        #     array=error_x_values,
        #     visible=True,
        #     thickness=1.5,
        #     width=8,
        #     color=color
        # )
    ))

    x_range = np.linspace(axis_range[0],axis_range[1], 2)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
    ))

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression[experimental_data], df_lineair_regression[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression[experimental_data], df_lineair_regression[model_data])

    #number of symbols in sign
    n_s = len(f"R=0.00 p-value=0.00 MSE=0.00 ")
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0.0 / n_s),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.0) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"p-value={pvalue:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 + n_s3 * 0.0) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=32, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False
))


#Plot tytle
fig.update_layout(
    title_text=" Predicted Unfolding Rate",
    title_x=0.5,
    title_font=dict(size=32),
    width=1150,
    height=750,
    showlegend=True,
    plot_bgcolor="white",
    font=dict(family="Arial", size=32, color='black'),
    margin=dict(l=200, r=100, t=80, b=100)
)

#Set axis names and ranges
fig.update_xaxes(
    title_text="ln k<sub>u,exp</sub> (s<sup>−1</sup>)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=32),
    tickfont=dict(size=32),
    showline=True,
    linecolor="black",
    mirror=True,
)

fig.update_yaxes(
    title_text="ln k<sub>u,pred</sub> (s<sup>−1</sup>)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=32),
    tickfont=dict(size=32),
    showline=True,
    linecolor="black",
    mirror=True,
)

fig.show()

fig.write_image(f'{work_dir_path}/images/models_logku_v0.png', scale=1)

# %% [markdown]
# #### Plot all 3

# %%
fig = make_subplots(rows=1, cols=3, )
font_size = 20
color_list = ['Length, aa','CT parameters',]
colors = ['blue', 'red', 'green']

######################################## Plot energy #########################################
# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_energy', 'y_pred_CO_energy','y_pred_logCT_logEnergy']
predicted_list = ['y_pred_CO_energy','y_pred_logCT_logEnergy']
experimental_data = 'y_measured_energy'



axis_min = np.min(df_lineair_regression[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression[predicted_list+[experimental_data]])) // 1 )

axis_range = [axis_min, axis_max]



for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression[experimental_data], df_lineair_regression[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression[experimental_data],
        y= df_lineair_regression[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=10, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        
        ),
        row=1, col=1)

    x_range = np.linspace(axis_range[0],axis_range[1], 20)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
        
    ),
    row=1, col=1)

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression[experimental_data], df_lineair_regression[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression[experimental_data], df_lineair_regression[model_data])

    #number of symbols in sign
    n_s = len(f"R=0.00 p-value=0.00 MSE=0.00 ")
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / n_s),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=1
    )
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"p-value={pvalue:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=1
    )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 + n_s3 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=1
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False,
    ),
    row=1, col=1
    )


#Set axis names and ranges
fig.update_xaxes(
    title_text="∆𝐺<sub>exp</sub>(kcal/mol)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=1
)

fig.update_yaxes(
    title_text="∆𝐺<sub>pred</sub>(kcal/mol)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=1
)

################################################################################################################################################################

######################################## Plot kf #########################################
# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_logkf', 'y_pred_CO_logkf','y_pred_logCT_logkf']
predicted_list = ['y_pred_CO_logkf','y_pred_logCT_logkf']
experimental_data = 'y_measured_log10kf'

axis_min = np.min(df_lineair_regression[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression[predicted_list+[experimental_data]])) // 1 )

axis_range = [axis_min, axis_max]

for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression[experimental_data], df_lineair_regression[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression[experimental_data],
        y= df_lineair_regression[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=10, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        showlegend=False,
        ),
        row=1, col=2)

    x_range = np.linspace(axis_range[0],axis_range[1], 20)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
        
    ),
    row=1, col=2)

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression[experimental_data], df_lineair_regression[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression[experimental_data], df_lineair_regression[model_data])

    #number of symbols in sign
    n_s = len(f"R=0.00 p-value=0.00 MSE=0.00 ")
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / n_s),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=2
    )
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"p-value={pvalue:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=2
    )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 + n_s3 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=2
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False,
    ),
    row=1, col=2
    )


#Set axis names and ranges
fig.update_xaxes(
    title_text="ln k<sub>f,exp</sub>(kcal/mol)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=2
)

fig.update_yaxes(
    title_text="ln k<sub>f,pred</sub>(kcal/mol)",
    range=axis_range,
    dtick=1,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=2
)

################################################################################################################################################################

######################################## Plot ku #########################################
# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_logku', 'y_pred_CO_logku','y_pred_logCT_logku']
predicted_list = ['y_pred_CO_logku','y_pred_logCT_logku']
experimental_data = 'y_measured_log10ku'

axis_min = np.min(df_lineair_regression[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression[predicted_list+[experimental_data]])) // 1 )

axis_range = [axis_min, axis_max]

for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression[experimental_data], df_lineair_regression[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression[experimental_data],
        y= df_lineair_regression[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=10, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        showlegend=False,
        ),
        row=1, col=3)

    x_range = np.linspace(axis_range[0],axis_range[1], 20)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
        
    ),
    row=1, col=3)

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression[experimental_data], df_lineair_regression[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression[experimental_data], df_lineair_regression[model_data])

    #number of symbols in sign
    n_s = len(f"R=0.00 p-value=0.00 MSE=0.00 ")
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / n_s),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=3
    )
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"p-value={pvalue:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=3
    )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 + n_s3 * 0.) / n_s),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=font_size, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=3
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False,
    ),
    row=1, col=3
    )




#Set axis names and ranges
fig.update_xaxes(
    title_text="ln k<sub>u,exp</sub>(kcal/mol)",
    range=axis_range,
    dtick=2,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=3
)

fig.update_yaxes(
    title_text="ln k<sub>u,pred</sub>(kcal/mol)",
    range=axis_range,
    dtick=2,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=3
)

################################################################################################################################################################

#Plot tytle
fig.update_layout(
    # title_text=" Predicted free energy",
    # title_x=0.5,
    # title_font=dict(size=font_size),
    width=1800,
    height=600,
    showlegend=True,
    plot_bgcolor="white",
    font=dict(family="Arial", size=font_size, color='black'),
    # margin=dict(l=200, r=100, t=80, b=100),
    # row=1, col=1
)


fig.write_image(f'{work_dir_path}/images/models_all_train_v2_NO_CO.png', scale=5, 
    width=1800,
    height=600,)

fig.show()

# %% [markdown]
# ## Prediction model validation on ACPRO dataset

# %%
# Load in ACPRO dataframe or prepare in forst part of the code
ACPRO_df = pd.read_csv(f'{work_dir_path}\ACPRO_22avg.csv', index_col=0).loc[:, ['Chain', 'Protein Length', 'Contact Order','ln kf','Fragment start', 'Fragment end','Temperature', 'pH']]
ACPRO_df["PDB"] = ACPRO_df.index

ACPRO_df
# Out:
#        Chain  Protein Length  Contact Order  ln kf  Fragment start  \
# PDB Id
# 1A6N       A             151       14.00990   1.13             NaN
# 1ADW       A             123       15.36850   0.69             NaN
# 1AON       A             186       43.26270   0.18           191.0
# 1APS       A              98       20.72830  -1.58             NaN
# 1ARR       A              53        2.71281   9.20             NaN
# ...      ...             ...            ...    ...             ...
# 2VKN       A              70       13.46580   2.11             NaN
# 2WXC       A              47        4.50322  11.20             NaN
# 3CHY       A             128       11.31200   1.00             NaN
# 3F6R       A             148       15.19700   3.52             NaN
# 3M48       A              33        2.45394  12.90             NaN
#
#         Fragment end  Temperature   pH   PDB
# PDB Id
# 1A6N             NaN         5.00  6.2  1A6N
# 1ADW             NaN        15.00  7.0  1ADW
# 1AON           376.0        15.00  7.0  1AON
# 1APS             NaN        25.00  7.0  1APS
# 1ARR             NaN        25.00  7.5  1ARR
# ...              ...          ...  ...   ...
# 2VKN             NaN        25.00  7.0  2VKN
# 2WXC             NaN         9.85  7.0  2WXC
# 3CHY             NaN        25.00  7.0  3CHY
# 3F6R             NaN        20.00  7.0  3F6R
# 3M48             NaN         5.00  7.0  3M48
#
# [126 rows x 9 columns]

# %% [markdown]
# ### Dowload and pre-process PDBs

# %%
import urllib
import gzip
import shutil

for pdb in ACPRO_df.index:
    if not os.path.isfile('pdbs/{}.pdb'.format(pdb.lower())):
        if not os.path.isfile('pdbs_ACPRO/{}.pdb'.format(pdb.lower())):

            try:
                urllib.request.urlretrieve(f"https://files.wwpdb.org/pub/pdb/data/structures/divided/pdb/{pdb.lower()[1:3]}/pdb{pdb.lower()}.ent.gz", f'pdbs_ACPRO/{pdb.lower()}.ent.gz')

                with gzip.open(f'pdbs_ACPRO/{pdb.lower()}.ent.gz', 'rb') as f_in:
                    with open(f'pdbs_ACPRO/{pdb.lower()}.pdb', 'wb') as f_out:
                        shutil.copyfileobj(f_in, f_out)

            except:
                print(f"Problems with {pdb}")
                print(NameError)

# %%
def is_hydrogen(atom_name):
    return atom_name.startswith('H')

def extract_chain_from_pdb_lines(lines, target_chain_id, frag_start=None, frag_end=None):
    """
    Extracts lines for a specific chain (excluding hydrogens) from a list of PDB lines.
    If frag_start and frag_end are provided, only extracts residues within that range.
    Returns a list of frames (each frame is a list of lines).
    """
    frames = []
    current_frame = []
    inside_model = False

    for line in lines:
        record = line[:6].strip()

        if record == 'MODEL':
            inside_model = True
            current_frame = []
        elif record == 'ENDMDL':
            inside_model = False
            frames.append(current_frame)
        elif record == 'ATOM':
            chain_id = line[21].strip()
            atom_name = line[12:16].strip()
            res_seq = int(line[22:26].strip())

            if chain_id == target_chain_id and not is_hydrogen(atom_name):
                if frag_start is not None and frag_end is not None:
                    if not (frag_start <= res_seq <= frag_end):
                        continue  # Skip residues outside fragment range

                if not inside_model:
                    current_frame = []  # Start frame on-the-fly if no MODEL/ENDMDL
                    inside_model = True

                current_frame.append(line)

        elif record in ('TER', 'END') and inside_model:
            current_frame.append(line)

    if inside_model and current_frame:
        frames.append(current_frame)

    return frames

def process_pdbs_from_dataframe_simple(input_folder, output_folder, dataframe):
    os.makedirs(output_folder, exist_ok=True)
    df = dataframe.copy()

    df['PDB'] = df['PDB'].str.lower().str.strip()
    df['Chain'] = df['Chain'].str.strip()

    saved_files = []  # Track intermediate files

    for _, row in df.iterrows():
        pdb_name = row['PDB']
        chain_id = row['Chain']
        frag_start = row.get("Fragment start", np.nan)
        frag_end = row.get("Fragment end", np.nan)

        # Handle NaNs
        frag_start = int(frag_start) if not pd.isna(frag_start) else None
        frag_end = int(frag_end) if not pd.isna(frag_end) else None

        pdb_file = f"{pdb_name}.pdb"
        input_path = os.path.join(input_folder, pdb_file)

        if not os.path.exists(input_path):
            print(f"File not found: {pdb_file}")
            continue

        try:
            print(f"Processing: {pdb_file}, Chain: {chain_id}, Fragment: {frag_start}-{frag_end}")

            with open(input_path, 'r') as f:
                lines = f.readlines()

            # Extract frames of the specified chain and fragment
            frames = extract_chain_from_pdb_lines(lines, chain_id, frag_start, frag_end)

            if not frames:
                print(f"  Chain {chain_id} not found or no frames extracted.")
                continue

            for i, frame_lines in enumerate(frames):
                if frag_start is not None:
                    out_name = f"{pdb_name}_chain_{chain_id}_frag_{str(frag_start)}_frame_{i+1}.pdb"
                else: 
                    out_name = f"{pdb_name}_chain_{chain_id}_frag_0_frame_{i+1}.pdb"
                out_path = os.path.join(output_folder, out_name)
                with open(out_path, 'w') as out_f:
                    out_f.writelines(frame_lines)
                print(f"  Saved: {out_name}")
                saved_files.append(out_path)

        except Exception as e:
            print(f"  Failed to process {pdb_file}: {e}")

    # # === DELETE INTERMEDIATE FILES ===
    # for file_path in saved_files:
    #     try:
    #         os.remove(file_path)
    #         print(f"Deleted: {file_path}")
    #     except Exception as e:
    #         print(f"Failed to delete {file_path}: {e}")

# === USER SETTINGS ===
input_folder = f"{work_dir_path}\pdbs_ACPRO"       # Change this
output_folder = f"{work_dir_path}\pdbs_ACPRO_proc"     # Change this
dataframe = ACPRO_df[["PDB", "Chain", "Fragment start", "Fragment end"]]  # Include fragment columns

# === RUN ===
process_pdbs_from_dataframe_simple(input_folder, output_folder, dataframe)
# Out:
# Processing: 1a6n.pdb, Chain: A, Fragment: None-None
#   Saved: 1a6n_chain_A_frag_0_frame_1.pdb
# Processing: 1adw.pdb, Chain: A, Fragment: None-None
#   Saved: 1adw_chain_A_frag_0_frame_1.pdb
# Processing: 1aon.pdb, Chain: A, Fragment: 191-376
#   Saved: 1aon_chain_A_frag_191_frame_1.pdb
# File not found: 1aps.pdb
# Processing: 1arr.pdb, Chain: A, Fragment: None-None
#   Saved: 1arr_chain_A_frag_0_frame_1.pdb
# Processing: 1au7.pdb, Chain: A, Fragment: 103-160
#   Saved: 1au7_chain_A_frag_103_frame_1.pdb
# Processing: 1aue.pdb, Chain: A, Fragment: None-None
#   Saved: 1aue_chain_A_frag_0_frame_1.pdb
# Processing: 1avz.pdb, Chain: C, Fragment: None-None
#   Saved: 1avz_chain_C_frag_0_frame_1.pdb
# File not found: 1ayi.pdb
# Processing: 1b9c.pdb, Chain: A, Fragment: None-None
#   Saved: 1b9c_chain_A_frag_0_frame_1.pdb
# File not found: 1ba5.pdb
# Processing: 1bd8.pdb, Chain: A, Fragment: None-None
#   Saved: 1bd8_chain_A_frag_0_frame_1.pdb
# Processing: 1bf4.pdb, Chain: A, Fragment: None-None
#   Saved: 1bf4_chain_A_frag_0_frame_1.pdb
# Processing: 1bfe.pdb, Chain: A, Fragment: None-None
#   Saved: 1bfe_chain_A_frag_0_frame_1.pdb
# Processing: 1bni.pdb, Chain: A, Fragment: None-None
#   Saved: 1bni_chain_A_frag_0_frame_1.pdb
# Processing: 1bnz.pdb, Chain: A, Fragment: None-None
#   Saved: 1bnz_chain_A_frag_0_frame_1.pdb
# Processing: 1brs.pdb, Chain: D, Fragment: None-None
#   Saved: 1brs_chain_D_frag_0_frame_1.pdb
# File not found: 1c9o.pdb
# Processing: 1cdc.pdb, Chain: A, Fragment: None-None
#   Saved: 1cdc_chain_A_frag_0_frame_1.pdb
# File not found: 1csp.pdb
# Processing: 1cun.pdb, Chain: A_c_fragment, Fragment: 113-219
#   Chain A_c_fragment not found or no frames extracted.
# Processing: 1cun.pdb, Chain: A_n_fragment, Fragment: 7-112
#   Chain A_n_fragment not found or no frames extracted.
# File not found: 1div.pdb
# File not found: 1div.pdb
# Processing: 1e0g.pdb, Chain: A, Fragment: None-None
#   Saved: 1e0g_chain_A_frag_0_frame_1.pdb
#   Saved: 1e0g_chain_A_frag_0_frame_2.pdb
#   Saved: 1e0g_chain_A_frag_0_frame_3.pdb
#   Saved: 1e0g_chain_A_frag_0_frame_4.pdb
#   Saved: 1e0g_chain_A_frag_0_frame_5.pdb
#   Saved: 1e0g_chain_A_frag_0_frame_6.pdb
#   Saved: 1e0g_chain_A_frag_0_frame_7.pdb
#   Saved: 1e0g_chain_A_frag_0_frame
pdb
#   Saved: 2wxc_chain_A_frag_0_frame_19.pdb
#   Saved: 2wxc_chain_A_frag_0_frame_20.pdb
# Processing: 3chy.pdb, Chain: A, Fragment: None-None
#   Saved: 3chy_chain_A_frag_0_frame_1.pdb
# Processing: 3f6r.pdb, Chain: A, Fragment: None-None
#   Saved: 3f6r_chain_A_frag_0_frame_1.pdb
# Processing: 3m48.pdb, Chain: A, Fragment: None-None
#   Saved: 3m48_chain_A_frag_0_frame_1.pdb

# %% [markdown]
# ### Calculate Contact Order

# %%
CO_list_vasily = []
structure_names_list = []
pdb_list = []
L_list = []

for pdb in os.listdir('pdbs_ACPRO_proc'):
    pdb_path = "pdbs_ACPRO_proc/{}".format(pdb)
    print(pdb)
    abs_CO, L = abs_contact_order3(pdb_path)
    CO_list_vasily.append(abs_CO)

    # structure_names_list.append("{}_{}_{}".format(pdb.split("_")[0], pdb.split("_")[2], pdb.split("_")[4]))
    structure_names_list.append(pdb[:-4])
    pdb_list.append(pdb.split("_")[0])
    L_list.append(L)
# Out:
# 1a6n_chain_A_frag_0_frame_1.pdb
# Atoms:  1204
# L:  151
# 1adw_chain_A_frag_0_frame_1.pdb
# Atoms:  934
# L:  123
# 1aon_chain_A_frag_191_frame_1.pdb
# Atoms:  1362
# L:  186
# 1arr_chain_A_frag_0_frame_1.pdb
# Atoms:  435
# L:  53
# 1au7_chain_A_frag_103_frame_1.pdb
# Atoms:  482
# L:  58
# 1aue_chain_A_frag_0_frame_1.pdb
# Atoms:  781
# L:  92
# 1avz_chain_C_frag_0_frame_1.pdb
# Atoms:  463
# L:  57
# 1b9c_chain_A_frag_0_frame_1.pdb
# Atoms:  1774
# L:  224
# 1bd8_chain_A_frag_0_frame_1.pdb
# Atoms:  1168
# L:  156
# 1bf4_chain_A_frag_0_frame_1.pdb
# Atoms:  502
# L:  63
# 1bfe_chain_A_frag_0_frame_1.pdb
# Atoms:  826
# L:  110
# 1bni_chain_A_frag_0_frame_1.pdb
# Atoms:  851
# L:  108
# 1bnz_chain_A_frag_0_frame_1.pdb
# Atoms:  510
# L:  64
# 1brs_chain_D_frag_0_frame_1.pdb
# Atoms:  693
# L:  87
# 1cdc_chain_A_frag_0_frame_1.pdb
# Atoms:  759
# L:  96
# 1e0g_chain_A_frag_0_frame_1.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_10.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_11.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_12.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_13.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_14.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_15.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_16.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_17.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_18.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_19.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_2.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_20.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_3.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_4.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_5.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_6.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_7.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_8.pdb
# Atoms:  382
# L:  48
# 1e0g_chain_A_frag_0_frame_9.pdb
# Atoms:  382
# L:  48
# 1e0m_chain_A_frag_0_frame_1.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_10.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_2.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_3.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_4.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_5.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_6.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_7.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_8.pdb
# Atoms:  307
# L:  37
# 1e0m_chain_A_frag_0_frame_9.pdb
# Atoms:  307
# L:  37
# 1e41_chain_A_frag_93_frame_1.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_10.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_11.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_12.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_13.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_14.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_15.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_16.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_17.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_18.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_19.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_2.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_20.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_21.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_22.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_23.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_24.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_25.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_3.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_4.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_5.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_6.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame_7.pdb
# Atoms:  801
# L:  100
# 1e41_chain_A_frag_93_frame
pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_10.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_11.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_12.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_13.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_14.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_15.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_16.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_17.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_18.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_19.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_2.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_20.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_21.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_22.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_23.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_24.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_25.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_26.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_27.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_28.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_29.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_3.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_30.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_31.pdb
# Atoms:  314
# L:  42
# 2pdd_chain_A_frag_0_frame_32.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_33.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_34.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_35.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_4.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_5.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_6.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_7.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_8.pdb
# Atoms:  321
# L:  43
# 2pdd_chain_A_frag_0_frame_9.pdb
# Atoms:  321
# L:  43
# 2qjl_chain_A_frag_0_frame_1.pdb
# Atoms:  775
# L:  99
# 2rn2_chain_A_frag_0_frame_1.pdb
# Atoms:  1238
# L:  155
# 2vkn_chain_A_frag_0_frame_1.pdb
# Atoms:  539
# L:  66
# 2wxc_chain_A_frag_0_frame_1.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_10.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_11.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_12.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_13.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_14.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_15.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_16.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_17.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_18.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_19.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_2.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_20.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_3.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_4.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_5.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_6.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_7.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_8.pdb
# Atoms:  352
# L:  47
# 2wxc_chain_A_frag_0_frame_9.pdb
# Atoms:  352
# L:  47
# 3chy_chain_A_frag_0_frame_1.pdb
# Atoms:  979
# L:  128
# 3f6r_chain_A_frag_0_frame_1.pdb
# Atoms:  1093
# L:  147
# 3m48_chain_A_frag_0_frame_1.pdb
# Atoms:  238
# L:  30

# %%
df_co = pd.DataFrame({"PDB": pdb_list,"Structure name": structure_names_list, "CO": CO_list_vasily, "Length, aa": L_list, })
df_co["PDB"].unique()
df_co["CO, %"] = df_co["CO"] / df_co["Length, aa"] * 100

# %% [markdown]
# ### Cast final dataframe

# %%
# Merge data frames
ACPRO_df = ACPRO_df.reset_index()
ACPRO_df['PDB'] = ACPRO_df['PDB'].str.lower()
ACPRO_df_VA = pd.merge(ACPRO_df, df_co, on='PDB', how='inner')


# Import PCS data and merge with "results"
df_psc = pd.read_csv(f'{work_dir_path}\ACPRO_PSC_VA_v1.csv', index_col=0)
df_psc = df_psc.rename(columns={"protid": "Structure name"})
df_psc = df_psc.rename(columns={"C": "X"})

df_psc.loc[:,'Structure name'] = [name[:-2] for name in df_psc["Structure name"]]

print(df_psc.columns)
ACPRO_df_VA = pd.merge(df_psc, ACPRO_df_VA, on='Structure name', how='inner')

ACPRO_df_VA['log(P)'] = np.log(ACPRO_df_VA["P"])
ACPRO_df_VA['log(S)'] = np.log(ACPRO_df_VA["S"])
ACPRO_df_VA['log(X)'] = np.log(ACPRO_df_VA["X"])

ACPRO_df_VA['P_normalized'] = ACPRO_df_VA["P"]/(ACPRO_df_VA["Length, aa"]**1.79*(10**(-0.41)))
ACPRO_df_VA["S_normalized"] = ACPRO_df_VA["S"]/(ACPRO_df_VA["Length, aa"]**2.68*(10**(-2.11)))
ACPRO_df_VA["X_normalized"] = ACPRO_df_VA["X"]/(ACPRO_df_VA["Length, aa"]**1.72*(10**(-0.57)))

# Count occurrences of each PDB value
pdb_counts = ACPRO_df_VA['PDB'].value_counts()
# Compute weights: inverse of the count
weights = 1 / pdb_counts
# Map the weights back to the DataFrame
ACPRO_df_VA['weights'] = ACPRO_df_VA['PDB'].map(weights)


ACPRO_df_VA = ACPRO_df_VA.loc[ACPRO_df_VA['P']!=0]
ACPRO_df_VA = ACPRO_df_VA.loc[ACPRO_df_VA['S']!=0]
ACPRO_df_VA = ACPRO_df_VA.loc[ACPRO_df_VA['X']!=0]
ACPRO_df_VA = ACPRO_df_VA[~ACPRO_df_VA["ln kf"].isna()]

ACPRO_df_VA.to_csv(f'{work_dir_path}\ACPRO_result_VA_v1.csv')


ACPRO_df_VA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 ACPRO_df = ACPRO_df.reset_index()
#       3 ACPRO_df['PDB'] = ACPRO_df['PDB'].str.lower()
# ----> 4 ACPRO_df_VA = pd.merge(ACPRO_df, df_co, on='PDB', how='inner')
#       7 # Import PCS data and merge with "results"
#       8 df_psc = pd.read_csv(f'{work_dir_path}\ACPRO_PSC_VA_v1.csv', index_col=0)
#
# NameError: name 'df_co' is not defined

# %% [markdown]
# ### Load ACPRO data (CT and free energy) and average replicates

# %%
ACPRO_df_VA = pd.read_csv(f'{work_dir_path}\ACPRO_result_VA_v1.csv')

columns_to_average = ["Length, aa","CO", "log(P)", "log(S)", "log(X)", "ln kf"]

ACPRO_df_VA_avg = ACPRO_df_VA.groupby('PDB')[columns_to_average].mean().reset_index()
ACPRO_df_VA_avg["weights"] = 1.0
ACPRO_df_VA_avg["Length^2/3"] = ACPRO_df_VA_avg["Length, aa"] ** (2/3)
ACPRO_df_VA_avg = ACPRO_df_VA_avg.rename(columns={"ln kf": "ln(kf)_H2O"})

ACPRO_df_VA_avg
# Out:
#      PDB  Length, aa         CO    log(P)     log(S)    log(X)  ln(kf)_H2O  \
# 0   1a6n       151.0  12.657346  8.851807  10.265523  7.582229        1.13
# 1   1adw       123.0  15.368533  8.072467   9.206734  7.857094        0.69
# 2   1arr        53.0   2.712812  4.653960   7.319865  5.370638        9.20
# 3   1aue        92.0   9.874698  8.065894   9.392579  7.160846        5.37
# 4   1avz        57.0  11.184179  7.011214   6.815640  5.976351        4.88
# ..   ...         ...        ...       ...        ...       ...         ...
# 62  2vkn        66.0  13.550933  7.527794   6.566672  6.070738        2.11
# 63  2wxc        47.0   4.620003  5.404370   6.798646  5.102411       11.20
# 64  3chy       128.0  11.150345  7.989221   9.568504  7.289611        1.00
# 65  3f6r       147.0  15.196951  8.386401   9.669409  7.854769        3.52
# 66  3m48        30.0   2.423795  3.761200   6.749931  5.214936       12.90
#
#     weights  Length^2/3
# 0       1.0   28.356413
# 1       1.0   24.732617
# 2       1.0   14.109683
# 3       1.0   20.379423
# 4       1.0   14.810961
# ..      ...         ...
# 62      1.0   16.331621
# 63      1.0   13.023626
# 64      1.0   25.398417
# 65      1.0   27.853400
# 66      1.0    9.654894
#
# [67 rows x 9 columns]

# %% [markdown]
# ## Read and prepare ProThermdDB

# %% [markdown]
# ### Dowload and preprocess PDBs

# %%
df_ProThermdDB = pd.read_csv(f'{work_dir_path}\ProThermDB.csv', index_col=0, on_bad_lines='skip')
print(df_ProThermdDB.columns)

df_ProThermdDB.rename(columns={"PDB_wild": "PDB", 
                               "MUTATED_CHAIN":"Chain",
                               "Fragment Start":"Fragment start",
                               "Fragment End":"Fragment end",},
                      inplace=True)
# Out:
# Index(['PDB_wild', 'MUTATION_PDB', 'MUTATED_CHAIN', 'T', 'ln(kf)_H2O',
#        'ln(ku)_H2O', 'K_diff', 'Energy. kcal/mol', 'log(Energy', ' kcal/mol)',
#        'Folding Type', 'Fragment Start', 'Fragment End'],
#       dtype='object')

# %%
import urllib

for pdb in df_ProThermdDB.PDB_wild.unique():
    if not os.path.isfile('pdbs_proc_ProThermdDB/{}.pdb'.format(pdb)):
        try:
            urllib.request.urlretrieve('https://files.rcsb.org/download/{}.pdb'.format(pdb.lower()), 'pdbs_proc_ProThermdDB/{}.pdb'.format(pdb.lower()))
        except:
            print(f"Problems with {pdb}")

# %%
def is_hydrogen(atom_name):
    return atom_name.startswith('H')

def extract_chain_from_pdb_lines(lines, target_chain_id, frag_start=None, frag_end=None):
    """
    Extracts lines for a specific chain (excluding hydrogens) from a list of PDB lines.
    If frag_start and frag_end are provided, only extracts residues within that range.
    Returns a list of frames (each frame is a list of lines).
    """
    frames = []
    current_frame = []
    inside_model = False

    for line in lines:
        record = line[:6].strip()

        if record == 'MODEL':
            inside_model = True
            current_frame = []
        elif record == 'ENDMDL':
            inside_model = False
            frames.append(current_frame)
        elif record == 'ATOM':
            chain_id = line[21].strip()
            atom_name = line[12:16].strip()
            res_seq = int(line[22:26].strip())

            if chain_id == target_chain_id and not is_hydrogen(atom_name):
                if frag_start is not None and frag_end is not None:
                    if not (frag_start <= res_seq <= frag_end):
                        continue  # Skip residues outside fragment range

                if not inside_model:
                    current_frame = []  # Start frame on-the-fly if no MODEL/ENDMDL
                    inside_model = True

                current_frame.append(line)

        elif record in ('TER', 'END') and inside_model:
            current_frame.append(line)

    if inside_model and current_frame:
        frames.append(current_frame)

    return frames

def process_pdbs_from_dataframe_simple(input_folder, output_folder, dataframe):
    os.makedirs(output_folder, exist_ok=True)
    df = dataframe.copy()

    df['PDB'] = df['PDB'].str.lower().str.strip()
    df['Chain'] = df['Chain'].str.strip()

    saved_files = []  # Track intermediate files

    for _, row in df.iterrows():
        pdb_name = row['PDB']
        chain_id = row['Chain']
        frag_start = row.get("Fragment start", np.nan)
        frag_end = row.get("Fragment end", np.nan)

        # Handle NaNs
        frag_start = int(frag_start) if not pd.isna(frag_start) else None
        frag_end = int(frag_end) if not pd.isna(frag_end) else None

        pdb_file = f"{pdb_name}.pdb"
        input_path = os.path.join(input_folder, pdb_file)

        if not os.path.exists(input_path):
            print(f"File not found: {pdb_file}")
            continue

        try:
            print(f"Processing: {pdb_file}, Chain: {chain_id}, Fragment: {frag_start}-{frag_end}")

            with open(input_path, 'r') as f:
                lines = f.readlines()

            # Extract frames of the specified chain and fragment
            frames = extract_chain_from_pdb_lines(lines, chain_id, frag_start, frag_end)

            if not frames:
                print(f"  Chain {chain_id} not found or no frames extracted.")
                continue

            for i, frame_lines in enumerate(frames):
                if frag_start is not None:
                    out_name = f"{pdb_name}_chain_{chain_id}_frag_{str(frag_start)}_frame_{i+1}.pdb"
                else: 
                    out_name = f"{pdb_name}_chain_{chain_id}_frag_0_frame_{i+1}.pdb"
                out_path = os.path.join(output_folder, out_name)
                with open(out_path, 'w') as out_f:
                    out_f.writelines(frame_lines)
                print(f"  Saved: {out_name}")
                saved_files.append(out_path)

        except Exception as e:
            print(f"  Failed to process {pdb_file}: {e}")

    # # === DELETE INTERMEDIATE FILES ===
    # for file_path in saved_files:
    #     try:
    #         os.remove(file_path)
    #         print(f"Deleted: {file_path}")
    #     except Exception as e:
    #         print(f"Failed to delete {file_path}: {e}")

# === USER SETTINGS ===
input_folder = f"{work_dir_path}\pdbs_proc_ProThermdDB"       # Change this
output_folder = f"{work_dir_path}\pdbs_proc_ProThermdDB_proc"     # Change this
dataframe = df_ProThermdDB[["PDB", "Chain", "Fragment start", "Fragment end"]]  # Include fragment columns

# === RUN ===
process_pdbs_from_dataframe_simple(input_folder, output_folder, dataframe)
# Out:
# Processing: 1ril.pdb, Chain: A, Fragment: None-None
#   Saved: 1ril_chain_A_frag_0_frame_1.pdb
# Processing: 2pdd.pdb, Chain: A, Fragment: 43-None
#   Saved: 2pdd_chain_A_frag_43_frame_1.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_2.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_3.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_4.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_5.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_6.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_7.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_8.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_9.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_10.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_11.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_12.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_13.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_14.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_15.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_16.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_17.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_18.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_19.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_20.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_21.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_22.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_23.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_24.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_25.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_26.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_27.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_28.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_29.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_30.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_31.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_32.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_33.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_34.pdb
#   Saved: 2pdd_chain_A_frag_43_frame_35.pdb
# Processing: 2pdd.pdb, Chain: A, Fragment: 41-None
#   Saved: 2pdd_chain_A_frag_41_frame_1.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_2.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_3.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_4.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_5.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_6.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_7.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_8.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_9.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_10.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_11.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_12.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_13.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_14.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_15.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_16.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_17.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_18.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_19.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_20.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_21.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_22.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_23.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_24.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_25.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_26.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_27.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_28.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_29.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_30.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_31.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_32.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_33.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_34.pdb
#   Saved: 2pdd_chain_A_frag_41_frame_35.pdb
# Processing: 2pdd.pdb, Chain: A, Fragment: 39-None
#   Saved: 2pdd_chain_A_frag_39_frame_1.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_2.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_3.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_4.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_5.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_6.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_7.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_8.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_9.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_10.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_11.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_12.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_13.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_14.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_15.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_16.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_17.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_18.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_19.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_20.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_21.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_22.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_23.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_24.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_25.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_26.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_27.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_28.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_29.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_30.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_31.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_32.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_33.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_34.pdb
#   Saved: 2pdd_chain_A_frag_39_frame_35.pdb
# Processing: 1stn.pdb, Chain: A, Fragment: None-None
#   Saved: 1stn_chain_A_frag_0_frame_1.pdb
# Processing: 1a23.pdb, Chain: A, Fragment: None-None
#   Saved: 1a23_chain_A_frag_0_frame_1.pdb
# Processing: 1a23.pdb, Chain: A, Fragment: None-None
#   Saved: 1a23_chain_A_frag_0_frame_1.pdb
# Processing: 5azu.pdb, Chain: A, Fragment: None-None
#   Saved: 5azu_chain_A_frag_0_frame_1.pdb
# Processing: 1am7.pdb, Chain: A, Fragment: None-None
#   Saved: 1am7_chain_A_frag_0_frame_1.pdb
# Processing: 1ycc.pdb, Chain: A, Fragment: None-None
#   Saved: 1ycc_chain_A_frag_0_frame_1.pdb
# Processing: 1onc.pdb, Chain: A, Fragment: None-None
#   Saved: 1onc_chain_A_frag_0_frame_1.pdb
# Processing: 6if9.pdb, Chain: A, Fragment: 177-None
#   Saved: 6if9_chain_A_frag_177_frame_1.pdb
#   Saved: 6if9_chain_A_frag_177_frame_2.pdb
#   Saved: 6if9_chain_A_frag_177_frame_3.pdb
#   Saved: 6if9_chain_A_frag_177_frame_4.pdb
#   Saved: 6if9_chain_A_frag_177_frame_5.pdb
#   Saved: 6if9_chain_A_frag_177_frame_6.pdb
#   Saved: 6if9_chain_A_frag_177_frame_7.pdb
#   Saved: 6if9_chain_A_frag_177_frame_8.pdb
#   Saved: 6if9_chain_A_frag_177_frame_9.pdb
#   Saved: 6if9_chain_A_frag_177_frame_10.pdb
#   Saved: 6if9_chain_A_frag_177_frame_11.pdb
#   Saved: 6if9_chain_A_frag_177_frame_12.pdb
#   Saved: 6if9_chain_A_frag_177_frame_13.pdb
#   Saved: 6if9_chain_A_frag_177_frame_14.pdb
#   Saved: 6if9_chain_A_frag_177_frame_15.pdb
#   Saved: 6if9_chain_A_frag_177_frame_16.pdb
#   Saved: 6if9_chain_A_frag_177_frame_17.pdb
#   Saved: 6if9_chain_A_frag_177_frame_18.pdb
#   Saved: 6if9_chain_A_frag_177_frame_19.pdb
#   Saved: 6if9_chain_A_frag_177_frame_20.pdb
# Processing: 6if9.pdb, Chain: A, Fragment:
pdb
#   Saved: 1cx1_chain_A_frag_0_frame_21.pdb
#   Saved: 1cx1_chain_A_frag_0_frame_22.pdb
# Processing: 1g6n.pdb, Chain: A, Fragment: None-None
#   Saved: 1g6n_chain_A_frag_0_frame_1.pdb
# Processing: 1stn.pdb, Chain: A, Fragment: None-None
#   Saved: 1stn_chain_A_frag_0_frame_1.pdb
# Processing: 1rtb.pdb, Chain: A, Fragment: None-None
#   Saved: 1rtb_chain_A_frag_0_frame_1.pdb
# Processing: 1rtp.pdb, Chain: A, Fragment: None-None
#   Chain A not found or no frames extracted.
# Processing: 1rro.pdb, Chain: A, Fragment: None-None
#   Saved: 1rro_chain_A_frag_0_frame_1.pdb
# Processing: 1tca.pdb, Chain: A, Fragment: None-None
#   Saved: 1tca_chain_A_frag_0_frame_1.pdb

# %% [markdown]
# ### Calculate Contact Order

# %%
CO_list_vasily = []
structure_names_list = []
pdb_list = []
L_list = []

for pdb in os.listdir('pdbs_proc_ProThermdDB_proc'):
    pdb_path = "pdbs_proc_ProThermdDB_proc/{}".format(pdb)
    print(pdb)
    abs_CO, L = abs_contact_order3(pdb_path)
    CO_list_vasily.append(abs_CO)

    # structure_names_list.append("{}_{}_{}".format(pdb.split("_")[0], pdb.split("_")[2], pdb.split("_")[4]))
    structure_names_list.append(pdb[:-4])
    pdb_list.append(pdb.split("_")[0])
    L_list.append(L)
# Out:
# 1a23_chain_A_frag_0_frame_1.pdb
# Atoms:  1488
# L:  189
# 1akd_chain_A_frag_0_frame_1.pdb
# Atoms:  3208
# L:  405
# 1akk_chain_A_frag_0_frame_1.pdb
# Atoms:  824
# L:  104
# 1am7_chain_A_frag_0_frame_1.pdb
# Atoms:  1168
# L:  150
# 1aqh_chain_A_frag_0_frame_1.pdb
# Atoms:  3443
# L:  448
# 1b5m_chain_A_frag_0_frame_1.pdb
# Atoms:  676
# L:  84
# 1bni_chain_A_frag_0_frame_1.pdb
# Atoms:  851
# L:  108
# 1bta_chain_A_frag_0_frame_1.pdb
# Atoms:  720
# L:  89
# 1btl_chain_A_frag_0_frame_1.pdb
# Atoms:  2030
# L:  263
# 1c52_chain_A_frag_0_frame_1.pdb
# Atoms:  997
# L:  131
# 1cok_chain_A_frag_0_frame_1.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_10.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_11.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_12.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_13.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_14.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_15.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_16.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_17.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_18.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_2.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_3.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_4.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_5.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_6.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_7.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_8.pdb
# Atoms:  550
# L:  68
# 1cok_chain_A_frag_0_frame_9.pdb
# Atoms:  550
# L:  68
# 1cpm_chain_A_frag_0_frame_1.pdb
# Atoms:  1693
# L:  214
# 1csp_chain_A_frag_0_frame_1.pdb
# Atoms:  505
# L:  67
# 1cx1_chain_A_frag_0_frame_1.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_10.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_11.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_12.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_13.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_14.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_15.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_16.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_17.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_18.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_19.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_2.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_20.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_21.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_22.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_3.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_4.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_5.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_6.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_7.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_8.pdb
# Atoms:  1120
# L:  153
# 1cx1_chain_A_frag_0_frame_9.pdb
# Atoms:  1120
# L:  153
# 1div_chain_A_frag_149_frame_1.pdb
# Atoms:  1148
# L:  149
# 1do9_chain_A_frag_0_frame_1.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_10.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_11.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_12.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_13.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_14.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_15.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_16.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_17.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_18.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_19.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_2.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_20.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_21.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_22.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_23.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_24.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_25.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_26.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_27.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_28.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_29.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_3.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_30.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_31.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_32.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_33.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_34.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_35.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_36.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_37.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_38.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_39.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_4.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame_40.pdb
# Atoms:  767
# L:  94
# 1do9_chain_A_frag_0_frame
# Atoms:  4376
# L:  581
# 451c_chain_A_frag_0_frame_1.pdb
# Atoms:  610
# L:  82
# 4blm_chain_A_frag_0_frame_1.pdb
# Atoms:  2003
# L:  256
# 4lyz_chain_A_frag_0_frame_1.pdb
# Atoms:  1001
# L:  129
# 4u3h_chain_A_frag_0_frame_1.pdb
# Atoms:  740
# L:  100
# 5ax2_chain_A_frag_0_frame_1.pdb
# Atoms:  630
# L:  78
# 5azu_chain_A_frag_0_frame_1.pdb
# Atoms:  974
# L:  128
# 6if9_chain_A_frag_177_frame_1.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_10.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_11.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_12.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_13.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_14.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_15.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_16.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_17.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_18.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_19.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_2.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_20.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_3.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_4.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_5.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_6.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_7.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_8.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_177_frame_9.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_1.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_10.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_11.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_12.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_13.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_14.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_15.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_16.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_17.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_18.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_19.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_2.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_20.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_3.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_4.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_5.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_6.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_7.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_8.pdb
# Atoms:  1486
# L:  178
# 6if9_chain_A_frag_90_frame_9.pdb
# Atoms:  1486
# L:  178
# 7a1h_chain_A_frag_0_frame_1.pdb
# Atoms:  513
# L:  64
# 7z5g_chain_A_frag_0_frame_1.pdb
# Atoms:  2722
# L:  332

# %%
df_co = pd.DataFrame({"PDB": pdb_list,"Structure name": structure_names_list, "CO": CO_list_vasily, "Length, aa": L_list, })
df_co["PDB"].unique()
df_co["CO, %"] = df_co["CO"] / df_co["Length, aa"] * 100

# %% [markdown]
# ### Cast final dataframe

# %%
# Merge data frames
df_ProThermdDB = df_ProThermdDB.reset_index()
df_ProThermdDB['PDB'] = df_ProThermdDB['PDB'].str.lower()
df_ProThermdDB_VA = pd.merge(df_ProThermdDB, df_co, on='PDB', how='inner')


# Import PCS data and merge with "results"
df_psc = pd.read_csv(f'{work_dir_path}\ProThermdDB_PSC_VA_v1.csv', index_col=0)
df_psc = df_psc.rename(columns={"protid": "Structure name"})
df_psc = df_psc.rename(columns={"C": "X"})

df_psc.loc[:,'Structure name'] = [name[:-2] for name in df_psc["Structure name"]]

print(df_psc.columns)
df_ProThermdDB_VA = pd.merge(df_psc, df_ProThermdDB_VA, on='Structure name', how='inner')

df_ProThermdDB_VA['log(P)'] = np.log(df_ProThermdDB_VA["P"])
df_ProThermdDB_VA['log(S)'] = np.log(df_ProThermdDB_VA["S"])
df_ProThermdDB_VA['log(X)'] = np.log(df_ProThermdDB_VA["X"])
df_ProThermdDB_VA['P_normalized'] = df_ProThermdDB_VA["P"]/(df_ProThermdDB_VA["Length, aa"]**1.79*(10**(-0.41)))
df_ProThermdDB_VA["S_normalized"] = df_ProThermdDB_VA["S"]/(df_ProThermdDB_VA["Length, aa"]**2.68*(10**(-2.11)))
df_ProThermdDB_VA["X_normalized"] = df_ProThermdDB_VA["X"]/(df_ProThermdDB_VA["Length, aa"]**1.72*(10**(-0.57)))

# Count occurrences of each PDB value
pdb_counts = df_ProThermdDB_VA['PDB'].value_counts()
# Compute weights: inverse of the count
weights = 1 / pdb_counts
# Map the weights back to the DataFrame
df_ProThermdDB_VA['weights'] = df_ProThermdDB_VA['PDB'].map(weights)


df_ProThermdDB_VA = df_ProThermdDB_VA.loc[df_ProThermdDB_VA['P']!=0]
df_ProThermdDB_VA = df_ProThermdDB_VA.loc[df_ProThermdDB_VA['S']!=0]
df_ProThermdDB_VA = df_ProThermdDB_VA.loc[df_ProThermdDB_VA['X']!=0]
df_ProThermdDB_VA = df_ProThermdDB_VA[~df_ProThermdDB_VA["Energy. kcal/mol"].isna()]

df_ProThermdDB_VA.to_csv(f'{work_dir_path}\ProThermdDB_VA_v1.csv')
# Out:
# Index(['Structure name', 'P', 'S', 'X', 'I', 'T', 'L'], dtype='object')

# %% [markdown]
# ### Load ProThermdDB data (CT and free energy) and average replicates

# %%
df_ProThermdDB_VA = pd.read_csv(f'{work_dir_path}\ProThermdDB_VA_v1.csv')

columns_to_average = ["Length, aa","CO", "log(P)", "log(S)", "log(X)", "Energy. kcal/mol"]

df_ProThermdDB_VA_avg = df_ProThermdDB_VA.groupby('PDB')[columns_to_average].mean().reset_index()
df_ProThermdDB_VA_avg["weights"] = 1.0
df_ProThermdDB_VA_avg["Length^2/3"] = df_ProThermdDB_VA_avg["Length, aa"] ** (2/3)
df_ProThermdDB_VA_avg = df_ProThermdDB_VA_avg.rename(columns={"Energy. kcal/mol": "Energy, kcal/mol"})

df_ProThermdDB_VA_avg["log(Energy, kcal/mol)"] = np.log(df_ProThermdDB_VA_avg["Energy, kcal/mol"])

df_ProThermdDB_VA_avg
# Out:
# 58

# %% [markdown]
# ## Linear regression with combined data ACPRO, K-Pro, and ProThermdDB

# %%
#Make a merged data frames folding kinetics and free energy of folding
## Folding kinetics
# Step 1: Find common columns
common_cols = ACPRO_df_VA_avg.columns.intersection(KPro_df_VA_avg.columns)

# Step 2: Merge on those columns
merged_df_kf = pd.concat([ACPRO_df_VA_avg[common_cols], KPro_df_VA_avg[common_cols]], ignore_index=True)


## Free energy of folding
common_cols = df_ProThermdDB_VA_avg.columns.intersection(KPro_df_VA_avg.columns)

# Step 2: Merge on those columns
merged_df_fe = pd.concat([df_ProThermdDB_VA_avg[common_cols], KPro_df_VA_avg[common_cols]], ignore_index=True)
merged_df_fe = merged_df_fe.groupby('PDB').mean().reset_index() # group and use average values for same proteins (PDB)

# %%
fig = px.scatter_3d(merged_df_fe, 
                    x='log(P)', y='log(S)', z='log(X)',
                    color='log(Energy, kcal/mol)',
                    hover_name = "PDB",
                    width=800, height=400,
                    )
fig.update_traces(marker_size = 3)
fig.show()

# %%
fig = px.scatter(merged_df_fe, x="log(P)", y="log(Energy, kcal/mol)", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(merged_df_fe, x="log(S)", y="log(Energy, kcal/mol)", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()
fig = px.scatter(merged_df_fe, x="log(X)", y="log(Energy, kcal/mol)", hover_name = "PDB", color="Length, aa", width=800, height=400, opacity = 0.3)
fig.show()

# %%
len(merged_df_fe), len(merged_df_fe.PDB.unique())
# Out:
# (106, 106)

# %%
from sklearn.metrics import mean_squared_error
from scipy import stats

def evaluate_model(train, test, feature_columns, target_column, model_name):

    coefficients = []
    intercepts = []
    coefficient_errors = []
    intercept_errors = []
    

    X_train = train[feature_columns]
    y_train = train[target_column]

    X_test = test[feature_columns]
    y_test = test[target_column]
    
    

    X_train = sm.add_constant(X_train)
    X_test = sm.add_constant(X_test)
    
    # model = sm.WLS(y_train, X_train, weights=weights_train).fit()
    model = sm.OLS(y_train, X_train, ).fit()
    # print(model.params)

    intercepts.append(model.params['const'])
    coefficients.append(model.params.iloc[1:].values)
    coefficient_errors.append(model.bse.iloc[1:].values)
    intercept_errors.append(model.bse.iloc[0])

    avg_coefficients = np.mean(coefficients, axis=0)
    avg_intercept = np.mean(intercepts)
    avg_coefficient_errors = np.mean(coefficient_errors, axis=0)
    avg_intercept_error = np.mean(intercept_errors)
    
    formatted_coefficients = [round(coef, 3) for coef in avg_coefficients]
    formatted_coefficient_errors = [round(err, 3) for err in avg_coefficient_errors]
    
    MSE_train = mean_squared_error(y_train, model.predict(X_train))
    rpearson_train, pvalue_train = stats.pearsonr(y_train, model.predict(X_train))

    MSE_test = mean_squared_error(y_test, model.predict(X_test))
    rpearson_test, pvalue_test = stats.pearsonr(y_test, model.predict(X_test))
    
    result = {
        "Model": model_name,
        "Feature Columns": ", ".join(feature_columns),
        "Target Column": target_column,

        "Coefficients": formatted_coefficients,
        "Coefficient Errors": formatted_coefficient_errors,
        "Intercept": round(avg_intercept, 3),
        "Intercept Error": round(avg_intercept_error, 3),

        "MSE train": round(MSE_train, 3),
        "MSE test": round(MSE_test, 3),

        "R train": round(rpearson_train, 3),
        "R test": round(rpearson_test, 3),

        "p-value train": round(pvalue_train, 3),
        "p-value test": round(pvalue_test, 3),

    }
    return result


models = [
    {"model_name": "length_energy", "features": ['Length, aa'], "target": 'Energy, kcal/mol'},
    {"model_name": "CO_energy", "features": ['CO'], "target": 'Energy, kcal/mol'},
    {"model_name": "logCT_logEnergy", "features": ['log(P)', 'log(S)', 'log(X)'], "target": 'log(Energy, kcal/mol)'},

    {"model_name": "length_logkf", "features": ['Length, aa'], "target": 'ln(kf)_H2O'},
    {"model_name": "CO_logkf", "features": ['CO'], "target": 'ln(kf)_H2O'},
    {"model_name": "logCT_logkf", "features": ['log(P)', 'log(S)', 'log(X)'], "target": 'ln(kf)_H2O'},

    {"model_name": "length_logku", "features": ['Length, aa'], "target": 'ln(ku)_H2O'},
    {"model_name": "CO_logku", "features": ['CO'], "target": 'ln(ku)_H2O'},
    {"model_name": "logCT_logku", "features": ['log(P)', 'log(S)', 'log(X)'], "target": 'ln(ku)_H2O'},
]

results = []

#split data frame on test and train proteins structures
#1)
unique_proteins = merged_df_kf["PDB"].unique()
train_proteins, test_proteins = train_test_split(unique_proteins, test_size=0.5, random_state=6413468)
kf_train = merged_df_kf[merged_df_kf["PDB"].isin(train_proteins)]
kf_test = merged_df_kf[merged_df_kf["PDB"].isin(test_proteins)]
#2)
unique_proteins = KPro_df_VA_avg["PDB"].unique()
train_proteins, test_proteins = train_test_split(unique_proteins, test_size=0.5, random_state=3724761)
ku_train = KPro_df_VA_avg[KPro_df_VA_avg["PDB"].isin(train_proteins)]
ku_test = KPro_df_VA_avg[KPro_df_VA_avg["PDB"].isin(test_proteins)]
#3)
unique_proteins = merged_df_fe["PDB"].unique()
train_proteins, test_proteins = train_test_split(unique_proteins, test_size=0.5, random_state=9409344)
fe_train = merged_df_fe[merged_df_fe["PDB"].isin(train_proteins)]
fe_test = merged_df_fe[merged_df_fe["PDB"].isin(test_proteins)]



#train the models
for model in models:
    print(model)
    if model["target"] == 'ln(kf)_H2O': 
        result = evaluate_model(kf_train,kf_test,
                                feature_columns = model["features"],
                                target_column = model["target"],
                                model_name = model["model_name"])
    elif model["target"] == 'ln(ku)_H2O':
        result = evaluate_model(ku_train,ku_test,
                                feature_columns = model["features"],
                                target_column = model["target"],
                                model_name = model["model_name"])
    else:
        result = evaluate_model(fe_train,fe_test,
                                feature_columns = model["features"],
                                target_column = model["target"],
                                model_name = model["model_name"])
        
    results.append(result)

merged_regression_VA = pd.DataFrame(results)
merged_regression_VA['params'] = merged_regression_VA.apply(lambda row: row['Coefficients'] + [row['Intercept']], axis=1)
merged_regression_VA['name_list'] = [
                'Length, aa vs Energy',
                'Contact Order  vs Energy',
                'Log P, S, X vs logEnergy',

                'Length, aa vs log folding rate',
                'Contact Order vs log folding rate',
                'Log P, S, X vs log folding rate',
                
                'Length, aa vs log unfolding rate',
                'Contact Order  vs log unfolding rate',
                'Log P, S, X vs log unfolding rate',
]
merged_regression_VA
# Out:
# {'model_name': 'length_energy', 'features': ['Length, aa'], 'target': 'Energy, kcal/mol'}
# {'model_name': 'CO_energy', 'features': ['CO'], 'target': 'Energy, kcal/mol'}
# {'model_name': 'logCT_logEnergy', 'features': ['log(P)', 'log(S)', 'log(X)'], 'target': 'log(Energy, kcal/mol)'}
# {'model_name': 'length_logkf', 'features': ['Length, aa'], 'target': 'ln(kf)_H2O'}
# {'model_name': 'CO_logkf', 'features': ['CO'], 'target': 'ln(kf)_H2O'}
# {'model_name': 'logCT_logkf', 'features': ['log(P)', 'log(S)', 'log(X)'], 'target': 'ln(kf)_H2O'}
# {'model_name': 'length_logku', 'features': ['Length, aa'], 'target': 'ln(ku)_H2O'}
# {'model_name': 'CO_logku', 'features': ['CO'], 'target': 'ln(ku)_H2O'}
# {'model_name': 'logCT_logku', 'features': ['log(P)', 'log(S)', 'log(X)'], 'target': 'ln(ku)_H2O'}
#              Model         Feature Columns          Target Column  \
# 0    length_energy              Length, aa       Energy, kcal/mol
# 1        CO_energy                      CO       Energy, kcal/mol
# 2  logCT_logEnergy  log(P), log(S), log(X)  log(Energy, kcal/mol)
# 3     length_logkf              Length, aa             ln(kf)_H2O
# 4         CO_logkf                      CO             ln(kf)_H2O
# 5      logCT_logkf  log(P), log(S), log(X)             ln(kf)_H2O
# 6     length_logku              Length, aa             ln(ku)_H2O
# 7         CO_logku                      CO             ln(ku)_H2O
# 8      logCT_logku  log(P), log(S), log(X)             ln(ku)_H2O
#
#               Coefficients     Coefficient Errors  Intercept  Intercept Error  \
# 0                  [0.024]                [0.005]      3.723            0.698
# 1                  [0.351]                [0.055]      1.877            0.806
# 2   [0.016, -0.087, 0.457]  [0.193, 0.095, 0.201]     -0.811            0.378
# 3                 [-0.037]                [0.009]      7.976            1.011
# 4                 [-0.378]                [0.057]      9.220            0.815
# 5  [-1.862, 1.794, -1.842]  [0.959, 0.541, 1.306]     16.216            2.675
# 6                 [-0.197]                [0.035]     12.375            2.773
# 7                  [-1.12]                [0.156]      9.610            1.835
# 8  [-4.128, 2.137, -3.662]  [3.195, 1.224, 4.027]     34.068            6.944
#
#    MSE train  MSE test  R train  R test  p-value train  p-value test  \
# 0      9.041    14.087    0.567   0.314            0.0         0.022
# 1      7.346    10.825    0.670   0.519            0.0         0.000
# 2      0.185     0.223    0.721   0.672            0.0         0.000
# 3      9.218    13.898    0.466   0.522            0.0         0.000
# 4      6.622     9.456    0.661   0.744            0.0         0.000
# 5      6.782     9.816    0.651   0.703            0.0         0.000
# 6     13.670    15.812    0.762   0.720            0.0         0.000
# 7     10.084     8.847    0.831   0.857            0.0         0.000
# 8     12.519    10.017    0.785   0.865            0.0         0.000
#
#                             params                             name_list
# 0                   [0.024, 3.723]                  Length, aa vs Energy
# 1                   [0.351, 1.877]              Contact Order  vs Energy
# 2   [0.016, -0.087, 0.457, -0.811]              Log P, S, X vs logEnergy
# 3                  [-0.037, 7.976]        Length, aa vs log folding rate
# 4                   [-0.378, 9.22]     Contact Order vs log folding rate
# 5  [-1.862, 1.794, -1.842, 16.216]       Log P, S, X vs log folding rate
# 6                 [-0.197, 12.375]      Length, aa vs log unfolding rate
# 7                    [-1.12, 9.61]  Contact Order  vs log unfolding rate
# 8  [-4.128, 2.137, -3.662, 34.068]     Log P, S, X vs log unfolding rate

# %%
len(fe_train),len(fe_test)
# Out:
# (53, 53)

# %%
merged_regression_VA.to_csv(f'{work_dir_path}\merged_regression_VA_v2.csv')

# %%
def pred_dG(spx_vec, param):
    dG = np.dot(spx_vec, param[:-1]) + param[-1]
    return dG

data = {
    "y_measured_log10kf": kf_test['ln(kf)_H2O'],

    "y_pred_length_logkf": pred_dG(kf_test[['Length, aa']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="length_logkf","params"].values[0])),
    "y_pred_CO_logkf": pred_dG(kf_test[['CO']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="CO_logkf","params"].values[0])),
    "y_pred_logCT_logkf": pred_dG(kf_test[['log(P)', 'log(S)', 'log(X)']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="logCT_logkf","params"].values[0])),
    
}

#Take the mean of values for structures of a protein
df_lineair_regression2 = pd.DataFrame(data)
df_lineair_regression2['PDB'] = kf_test['PDB']
df_lineair_regression2
# Out:
#      y_measured_log10kf  y_pred_length_logkf  y_pred_CO_logkf  \
# 0              1.130000             2.389000         4.435523
# 1              0.690000             3.425000         3.410694
# 7              6.950000             5.645000         6.329645
# 8              3.000000             3.906000         3.299065
# 9              2.560000             3.980000         4.586016
# 11             3.470000             4.757000         5.216565
# 12             1.790000             4.424000         6.988430
# 14             8.850000             6.607000         7.008373
# 17            10.590000             5.978000         6.437204
# 18             4.040000            -8.193000         1.266199
# 20             4.380000             4.720000         2.271406
# 22             6.100000             3.203000         3.933383
# 24             8.250000             4.128000         4.811197
# 25            -4.000000             2.389000         2.067289
# 26             8.730000             5.978000         7.148444
# 32             3.040000             4.720000         3.554984
# 33             6.800000             4.979000         4.807672
# 35            13.800000             6.015000         7.081956
# 37            -4.700000            -4.141500        -1.140274
# 38             4.220000             4.387000         6.453173
# 39             8.740000             4.165000         4.685707
# 41             3.560000             4.683000         3.232305
# 42             5.480000             4.498000         4.804610
# 45            12.600000             6.644000         7.696669
# 46            12.250000             6.089000         7.237872
# 48             1.280000             3.869000         4.237402
# 53             5.350000             5.571000         6.466599
# 55             5.630000             4.794000         5.167155
# 59             9.690000             6.402971         7.497747
# 62             2.110000             5.534000         4.097747
# 63            11.200000             6.237000         7.473639
# 64             1.000000             3.240000         5.005170
# 66            12.900000             6.866000         8.303805
# 67             4.840000             3.314000         1.336440
# 68             5.910000             6.015000         6.831361
# 69            11.700000             5.756000         7.171746
# 70             7.220000             5.534000         5.003785
# 73             5.526667             5.238000         5.464440
# 75            10.050000             6.607000         6.918796
# 76             8.730000             5.793000         6.901835
# 78             6.340000             5.534000         4.855926
# 80             8.400000             6.496000         6.514973
# 81             2.470000             5.830000         4.954039
# 82             7.440000             2.389000         1.991942
# 85             3.980000             5.164000         3.972597
# 86             5.290000             5.423000         5.056255
# 89             2.700000             4.831000         3.556132
# 93            -0.360000             3.721000         3.302253
# 95             5.830000             4.387000         2.271185
# 97             9.080000             5.423000         6.179689
# 101           11.480000             5.682000         6.922111
# 102            8.520000             4.794000         5.273645
# 104            7.700000             5.423000         5.972855
# 105           10.230000             6.311000         6.794310
# 106            0.410000             4.535000         2.075711
# 108           12.240000             5.275000         6.588348
# 109            6.180000             4.794000         4.578318
# 111            7.310000             5.904000         7.105087
# 113            0.840000             4.498000         1.842093
#
#      y_pred_logCT_logkf   PDB
# 0              4.183818  1a6n
# 1              3.229179  1adw
# 7              7.230578  1bf4
# 8              3.098687  1bfe
# 9              4.110169  1bni
# 11             4.332955  1brs
# 12             7.653815  1cdc
# 14             6.186690  1e0m
# 17             5.319239  1enh
# 18             2.421341  1fmk
# 20             0.587577  1gxt
# 22             4.347590  1hel
# 24             4.535149  1hrc
# 25             2.353693  1i1b
# 26             7.523125  1idy
# 32             2.474344  1nps
# 33             4.437316  1pba
# 35             7.134002  1prb
# 37             1.156715  1qop
# 38             7.118595  1sce
# 39             4.427872  1spr
# 41             2.928646  1tit
# 42             5.676018  1ttf
# 45             8.487566  1vii
# 46             7.208887  1w4j
# 48             4.390938  1yea
# 53             6.326522  2cro
# 55             5.029010  2fdq
# 59             9.464535  2pdd
# 62             2.797559  2vkn
# 63             8.951192  2wxc
# 64             5.078504  3chy
# 66            11.716110  3m48
# 67             1.119877  1azu
# 68             6.593495  1ba5
# 69             6.991007  1bdc
# 70             4.765073  1c9o
# 73             6.031757  1div
# 75             6.363153  1e0l
# 76             7.116378  1fex
# 78             3.617844  1g6p
# 80             5.037502  1jmq
# 81             3.739592  1jo8
# 82             2.030512  1k0s
# 85             3.227312  1m9s
# 86             4.702461  1mjc
# 89             3.736049  1opd
# 93             1.822480  1qtu
# 95             2.408952  1ris
# 97             5.312319  1ryk
# 101            6.073906  1ss1
# 102            5.669151  1st7
# 104            4.991930  1uzc
# 105            6.076723  1w4e
# 106            0.614837  1wit
# 108            8.284449  2a3d
# 109            3.727980  2abd
# 111            6.728924  2jws
# 113            0.005067  2vh7

# %%
def pred_dG(spx_vec, param):
    dG = np.dot(spx_vec, param[:-1]) + param[-1]
    return dG

data = {
    "y_measured_log10ku": ku_test['ln(ku)_H2O'],

    "y_pred_length_logku": pred_dG(ku_test[['Length, aa']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="length_logku","params"].values[0])),
    "y_pred_CO_logku": pred_dG(ku_test[['CO']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="CO_logku","params"].values[0])),
    "y_pred_logCT_logku": pred_dG(ku_test[['log(P)', 'log(S)', 'log(X)']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="logCT_logku","params"].values[0])),
}

#Take the mean of values for structures of a protein
df_lineair_regression1 = pd.DataFrame(data)
df_lineair_regression1['PDB'] = ku_test['PDB']
df_lineair_regression1
# Out:
#     y_measured_log10ku  y_pred_length_logku  y_pred_CO_logku  \
# 2             4.220000               0.5550         3.541100
# 6            -2.626667              -2.2030        -1.517585
# 7            -2.730000              -1.8090        -2.312698
# 8             5.830000               5.0860         2.791618
# 10           -8.280000              -8.7040       -11.582175
# 11           -4.020000              -0.6270        -3.320589
# 13            6.700000               4.4950         1.595106
# 14           -2.720000               0.9490        -3.029885
# 15          -12.050000             -17.3720       -11.806469
# 16           -8.050000              -4.7640        -8.213313
# 18           -1.660000              -2.5970        -5.937860
# 19            1.440000              -1.2180        -2.727022
# 21           -0.575000              -3.5820        -3.318323
# 23           -1.720000               1.3430        -1.248726
# 25           -9.310000              -4.5670        -5.317995
# 26          -11.110000             -10.2800        -7.924065
# 27           -2.885000              -2.6955        -4.405557
# 33           -4.220000               1.1460        -2.585665
# 34            3.220000               0.1610         2.801441
# 38            3.000000               3.5100         2.422770
# 41            7.830000              -2.0060         1.812513
# 42           -6.510000              -4.5670        -4.143132
# 46           -6.500000              -6.1430       -12.250466
# 47           -2.800000             -12.4470        -7.688066
# 49            1.060000               1.7370         2.710199
# 50            3.210000              -3.3850         1.095209
#
#     y_pred_logCT_logku   PDB
# 2             1.887715  1bdc
# 6            -0.225061  1div
# 7            -2.402265  1dkt
# 8             4.245147  1e0l
# 10          -10.281415  1fkb
# 11           -4.614439  1g6p
# 13            1.055329  1jmq
# 14           -3.834295  1jo8
# 15          -10.969561  1k0s
# 16           -7.530676  1k8m
# 18           -5.104185  1m9s
# 19           -1.979367  1mjc
# 21           -3.171008  1o6x
# 23           -2.596943  1pgb
# 25           -4.207713  1prs
# 26          -11.155811  1qtu
# 27           -5.706877  1rfa
# 33           -4.667651  1shg
# 34           -0.526350  1ss1
# 38            1.289948  1w4e
# 41            4.201834  2a3d
# 42           -7.061639  2abd
# 46          -13.148368  2vh7
# 47          -10.393526  2vik
# 49            1.899501  2vxd
# 50            0.117628  3kz3

# %%
def pred_dG(spx_vec, param):
    dG = np.dot(spx_vec, param[:-1]) + param[-1]
    return dG

data = {
    "y_measured_energy": fe_test['Energy, kcal/mol'],

    "y_pred_length_energy": (pred_dG(fe_test[['Length, aa']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="length_energy",'params'].values[0]))),
    "y_pred_CO_energy": (pred_dG(fe_test[['CO']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="CO_energy","params"].values[0]))),
    "y_pred_logCT_Energy": np.exp(pred_dG(fe_test[['log(P)', 'log(S)', 'log(X)']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="logCT_logEnergy","params"].values[0]))),
}

#Take the mean of values for structures of a protein
df_lineair_regression3 = pd.DataFrame(data)
df_lineair_regression3['PDB'] = fe_test['PDB']
df_lineair_regression3
# Out:
#      y_measured_energy  y_pred_length_energy  y_pred_CO_energy  \
# 4            12.916172              6.747000          9.197449
# 6             4.610159              5.163000          3.778950
# 8             5.620000              5.859000          5.696172
# 10            4.544360              5.307000          5.792056
# 13            9.000000              8.859000         13.971826
# 14            2.255895              5.331000          5.732585
# 16            5.300364              6.399000          5.449760
# 21            5.640457              6.291000          8.518476
# 22            9.380000             12.555000          7.826137
# 23            3.730000              7.755000          7.552359
# 25            7.320000              8.523000          7.157148
# 26            6.138144              5.307000          5.929354
# 27            5.000000              5.763000          5.587556
# 30            3.913333              6.675000          6.327611
# 32            5.963636              5.787000          5.521452
# 33            1.007224              4.683000          4.388810
# 39            3.341615              5.547000          6.749588
# 40            2.281067              5.379000          5.743334
# 41            3.495661              6.027000          6.642812
# 44            5.167209              5.763000          7.136306
# 47            3.652582              5.787000          6.785226
# 49            6.283763              6.483000          7.372051
# 50            6.472898              5.559000          6.269375
# 51           13.300000              7.251000          7.951552
# 52            8.543633              6.051000          8.329471
# 53            3.335690              5.067000          5.865548
# 54            7.820000              6.195000          6.424220
# 55            2.700000              6.315000          5.443515
# 59            7.240166              6.195000          6.037475
# 60            3.464062              5.091000          5.699034
# 62            8.269003              5.787000          5.541472
# 63            4.250000              6.987000          6.638064
# 64           10.550000             11.331000         10.479247
# 66            9.540000              6.555000          5.702887
# 68           20.000000              9.939000         14.359506
# 70            5.004095              5.955000          8.510983
# 71            5.740000              8.163000         13.966986
# 75            1.800000              5.139000          5.902812
# 77            7.229297              5.787000          6.187133
# 78            3.820000              8.955000          8.847692
# 81            1.500000              5.619000          4.343459
# 83            8.210000              7.947000          8.063242
# 84           10.980000              7.659000          5.949778
# 85            1.676667              4.743343          3.476235
# 86            4.354764              5.595000          5.324322
# 88            9.150000              6.315000          6.239879
# 91            2.780121              5.067000          5.731335
# 92            3.342301              5.019000          4.039348
# 93            5.200000              6.387000          8.750873
# 95            4.875000             13.683000         11.519225
# 98            5.200000             17.667000          7.737848
# 99            7.200000              9.867000         10.800115
# 101          15.500000              6.123000          7.527005
#
#      y_pred_logCT_Energy   PDB
# 4               8.611318  1azu
# 6               3.798873  1bdc
# 8               6.559460  1bta
# 10              4.384577  1c9o
# 13             11.439127  1cpm
# 14              4.188182  1csp
# 16              4.612213  1div
# 21              7.426267  1fkb
# 22             10.537702  1fnf
# 23             10.126268  1ftg
# 25              8.110106  1g6n
# 26              5.643490  1g6p
# 27              5.090143  1grx
# 30              5.873837  1hfz
# 32              5.120439  1imq
# 33              3.386847  1jmq
# 39              5.244809  1m9s
# 40              4.414215  1mjc
# 41              5.922958  1n88
# 44              5.375606  1opd
# 47              4.248031  1pnj
# 49              8.969242  1qtu
# 50              5.548247  1rfa
# 51              7.808527  1ril
# 52              6.300520  1ris
# 53              3.704625  1rlq
# 54              6.361442  1rn1
# 55              5.037001  1rro
# 59              5.817606  1sha
# 60              4.855803  1shg
# 62              4.674461  1st7
# 63              7.013307  1stn
# 64             12.805311  1tca
# 66              5.446165  1tmy
# 68             16.318974  1v9e
# 70              8.583846  1wit
# 71             12.972680  1xxn
# 75              4.249659  2a36
# 77              6.039762  2abd
# 78              7.605566  2aky
# 81              2.924575  2jor
# 83              7.923718  2ks4
# 84              6.162877  2lzm
# 85              1.644557  2pdd
# 86              4.724365  2ptl
# 88              6.684618  2trx
# 91              4.509586  2vwf
# 92              4.003146  2vxd
# 93              8.499591  2w0k
# 95             10.275044  3pgk
# 98              9.742023  3v03
# 99              9.471046  4blm
# 101             6.679562  4u3h

# %% [markdown]
# #### Plot all 3

# %%
# def pred_dG(spx_vec, param):
#     dG = np.dot(spx_vec, param[:-1]) + param[-1]
#     return dG

# data = {
#     "y_measured_energy": fe_train['Energy, kcal/mol'],

#     "y_pred_length_energy": (pred_dG(fe_train[['Length, aa']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="length_energy",'params'].values[0]))),
#     "y_pred_CO_energy": (pred_dG(fe_train[['CO']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="CO_energy","params"].values[0]))),
#     "y_pred_logCT_Energy": np.exp(pred_dG(fe_train[['log(P)', 'log(S)', 'log(X)']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="logCT_logEnergy","params"].values[0]))),
# }

# #Take the mean of values for structures of a protein
# df_lineair_regression3_train = pd.DataFrame(data)
# df_lineair_regression3_train['PDB'] = fe_train['PDB']
# df_lineair_regression3_train
# Out:
#      y_measured_energy  y_pred_length_energy  y_pred_CO_energy  \
# 0            12.833333                 8.259          9.146331
# 1             9.480000                 6.219          5.646748
# 2             7.100000                 7.323          6.722016
# 3             8.330000                14.475         11.486579
# 5             2.814304                 4.995          4.095022
# 7             9.555000                 6.315          6.179985
# 9             7.500000                10.035         10.742950
# 11            8.635468                 5.259          5.350153
# 12            5.700000                 5.355          3.854582
# 15            5.380000                 7.395         11.301711
# 17            4.079407                 5.451          5.613488
# 18            2.374496                 4.611          4.013832
# 19            6.060000                 8.787          8.353182
# 20            3.460112                 5.139          4.029582
# 24            1.440000                 5.355          3.872688
# 28            9.100000                 7.923          9.412952
# 29            6.250000                 6.555          6.385992
# 31            2.700000                 5.571          4.301062
# 34            3.074997                 5.115          5.838250
# 35           11.547532                 7.347          8.588768
# 36            4.170181                 5.811          7.462699
# 37           16.680000                14.163         14.494362
# 38            0.629706                 4.203          3.239677
# 42            4.319215                 5.667          5.928644
# 43           13.700000                 6.195          7.052603
# 45            5.900000                 5.067          5.279768
# 46            4.751729                 5.067          5.280047
# 48            5.714805                 5.787          6.555327
# 56            9.022500                 6.699          7.164421
# 57            2.719506                 5.379          4.700146
# 58            2.988476                 5.811          4.531030
# 61            4.893926                 5.211          4.010754
# 65            6.690502                 5.883          7.291894
# 67            3.601132                 5.379          4.892206
# 69            4.283666                 4.803          4.129426
# 72            5.980000                 7.395          6.218469
# 73            3.390000                 4.563          3.203958
# 74            5.290891                 6.267          4.504121
# 76            2.612859                 5.475          4.320677
# 79            4.070372                 4.947          4.376739
# 80            5.020000                 4.947          4.965124
# 82            3.066589                 5.067          3.840847
# 87            3.010000                 6.147          6.814356
# 89            4.392598                 5.979          8.727914
# 90            5.916781                 6.747          7.298090
# 94            4.248117                 5.643          4.545475
# 96           10.600000                 5.979          7.885290
# 97           11.400000                 6.075          7.558825
# 100          11.255000                 6.819          6.730606
# 102          14.270000                 6.795          9.075908
# 103          13.863333                 7.995          7.698486
# 104           7.280000                 5.259          5.367431
# 105           9.020000                11.691         11.939732
#
#      y_pred_logCT_Energy   PDB
# 0               6.854164  1a23
# 1               4.258817  1akk
# 2               6.072020  1am7
# 3              14.056281  1aqh
# 5               3.927200  1ba5
# 7               6.198366  1bni
# 9               8.025829  1btl
# 11              4.559811  1coa
# 12              3.225917  1cok
# 15              7.851461  1cx1
# 17              4.367954  1dkt
# 18              2.705613  1e0l
# 19              9.281677  1edh
# 20              3.909835  1fex
# 24              3.418103  1ftt
# 28             10.820458  1gwy
# 29              4.081909  1hcd
# 31              2.533333  1hme
# 34              4.499585  1jo8
# 35              8.212765  1k0s
# 36              5.535049  1k8m
# 37             16.480108  1kfw
# 38              2.158495  1l2y
# 42              4.321202  1o6x
# 43              7.332736  1onc
# 45              4.960947  1pga
# 46              4.897975  1pgb
# 48              5.537682  1prs
# 56              7.932004  1rtb
# 57              4.786685  1ryk
# 58              4.800648  1sb0
# 61              4.428588  1ss1
# 65              6.042698  1ten
# 67              5.330352  1uzc
# 69              3.984233  1w4e
# 72              4.978553  1ymb
# 73              2.284452  1yrf
# 74              4.307276  1yyj
# 76              3.241053  2a3d
# 79              3.325678  2hbb
# 80              3.997184  2joo
# 82              4.092095  2jws
# 87              6.214007  2rdk
# 89              9.729911  2vh7
# 90              8.236097  2vik
# 94              4.291604  3kz3
# 96              7.180115  3tes
# 97              7.596065  3teu
# 100             5.712131  4lyz
# 102             9.600828  5azu
# 103            10.278810  6if9
# 104             4.544022  7a1h
# 105            12.977718  7z5g

# %%
experimental_data = 'y_measured_energy'
model_data = 'y_pred_logCT_Energy'
rpearson, pvalue = stats.pearsonr(df_lineair_regression3_train[experimental_data], df_lineair_regression3_train[model_data])
MSE = mean_squared_error(df_lineair_regression3_train[experimental_data], df_lineair_regression3_train[model_data])
print(f"Pearson R: {rpearson}, p-value: {pvalue}, MSE: {MSE}")
# Out:
# Pearson R: 0.6832979468862985, p-value: 1.7226731061661523e-08, MSE: 7.495219429022541

# %%
fig = make_subplots(rows=1, cols=3, horizontal_spacing= 0.1 )
font_size = 24

color_list = ['Length, aa', 'Contact Order','CT parameters']

colors = ['blue', 'red', 'green']

# color_list = ['CT parameters']
# colors = ['green',]
######################################## Plot energy #########################################
# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_energy', 'y_pred_CO_energy','y_pred_logCT_Energy']
# predicted_list = ['y_pred_logCT_Energy']


experimental_data = 'y_measured_energy'



axis_min = np.min(df_lineair_regression3[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression3[predicted_list+[experimental_data]])) // 1 )

axis_range = [axis_min, 22]



for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression3[experimental_data], df_lineair_regression3[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression3[experimental_data],
        y= df_lineair_regression3[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=8, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        
        ),
        row=1, col=1)

    x_range = np.linspace(axis_range[0],axis_range[1], 20)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
        
    ),
    row=1, col=1)

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression3[experimental_data], df_lineair_regression3[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression3[experimental_data], df_lineair_regression3[model_data])

    #number of symbols in sign
    
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / 18),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/8*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=font_size*0.8, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=1
    )
    # fig.add_annotation(
    #     x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
    #     y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
    #     text=f"p-value={pvalue:.2f}",
    #     showarrow=False,
    #     font=dict(size=font_size, color=color),
    #     xanchor="left",
    #     bgcolor="rgba(255, 255, 255, 0.7)",
    #     row=1, col=1
    # )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s3 * 0.) / 18),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/8*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=font_size*0.8, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=1
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False,
    ),
    row=1, col=1
    )


#Set axis names and ranges
fig.update_xaxes(
    title_text="∆𝐺<sub>exp</sub>(kcal/mol)",
    range=axis_range,
    dtick=3,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=1
)

fig.update_yaxes(
    title_text="∆𝐺<sub>pred</sub>(kcal/mol)",
    range=axis_range,
    dtick=3,
    title_standoff=0,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=1
)

################################################################################################################################################################

######################################## Plot kf #########################################
# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_logkf', 'y_pred_CO_logkf','y_pred_logCT_logkf']
# predicted_list = ['y_pred_logCT_logkf']
experimental_data = 'y_measured_log10kf'

axis_min = np.min(df_lineair_regression2[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression2[predicted_list+[experimental_data]])) // 1 )

axis_range = [axis_min, 20]

for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression2[experimental_data], df_lineair_regression2[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression2[experimental_data],
        y= df_lineair_regression2[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=8, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        showlegend=False,
        ),
        row=1, col=2)

    x_range = np.linspace(axis_range[0],axis_range[1], 20)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
        
    ),
    row=1, col=2)

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression2[experimental_data], df_lineair_regression2[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression2[experimental_data], df_lineair_regression2[model_data])

    #number of symbols in sign
    
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / 18),
        y = axis_range[1] - (axis_range[1]-axis_range[0])/8*(i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=font_size*0.8, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=2
    )
    # fig.add_annotation(
    #     x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
    #     y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
    #     text=f"p-value={pvalue:.2f}",
    #     showarrow=False,
    #     font=dict(size=font_size, color=color),
    #     xanchor="left",
    #     bgcolor="rgba(255, 255, 255, 0.7)",
    #     row=1, col=2
    # )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s3 * 0.) / 18),
        y=axis_range[1] - (axis_range[1]-axis_range[0])/8*(i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=font_size*0.8, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=2
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False,
    ),
    row=1, col=2
    )


#Set axis names and ranges
fig.update_xaxes(
    title_text="ln(k<sub>f,exp</sub>(s<sup>-1</sup>))",
    range=axis_range,
    dtick=6,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=2
)

fig.update_yaxes(
    title_text="ln(k<sub>f,pred</sub>(s<sup>-1</sup>))",
    range=axis_range,
    dtick=6,
    title_standoff=0,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=2
)

################################################################################################################################################################

######################################## Plot ku #########################################
# This code plots the CT parameters and contact order in the same plot
predicted_list = ['y_pred_length_logku', 'y_pred_CO_logku','y_pred_logCT_logku']
# predicted_list = ['y_pred_logCT_logku']

experimental_data = 'y_measured_log10ku'

axis_min = np.min(df_lineair_regression1[predicted_list+[experimental_data]]) // 1
axis_max = -((-np.max(df_lineair_regression1[predicted_list+[experimental_data]])) // 1 )

axis_range = [axis_min, 14]

for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):

    # Linear regression
    slope, intercept, rvalue, _, _ = stats.linregress(df_lineair_regression1[experimental_data], df_lineair_regression1[model_data])


    fig.add_trace(go.Scatter(
        x=df_lineair_regression1[experimental_data],
        y= df_lineair_regression1[model_data],
        mode="markers",
        marker_symbol='x',
        marker=dict(color=color, size=8, opacity=0.8,
                    line=dict(color="black", width=1)),
        name=f"{label}",
        showlegend=False,
        ),
        row=1, col=3)

    x_range = np.linspace(axis_range[0],axis_range[1], 20)
    y_pred = slope * x_range + intercept
    fig.add_trace(go.Scatter(
        x=x_range,
        y=y_pred,
        mode="lines",
        line=dict(color=color, width=3),
        showlegend=False,
        
    ),
    row=1, col=3)

#Calculate statistical parameters and add as anotations to the plot
for i, (model_data, label, color) in enumerate(zip(predicted_list, color_list, colors)):
    MSE = mean_squared_error(df_lineair_regression1[experimental_data], df_lineair_regression1[model_data])
    rpearson, pvalue = stats.pearsonr(df_lineair_regression1[experimental_data], df_lineair_regression1[model_data])

    #number of symbols in sign
    
    n_s1 = len(f"R={rpearson:.2f} ")
    n_s2 = len(f"p-value={pvalue:.2f} ")
    n_s3 = len(f"MSE = {MSE:.2f} ")

    fig.add_annotation(
        x = axis_range[0] + (axis_range[1]-axis_range[0]) * (n_s1 * 0. / 18),
        y = axis_range[1] - (axis_range[1]-axis_range[0]) / 8 * (i+0.5),
        text=f"R={rpearson:.2f}",
        showarrow=False,
        font=dict(size=font_size*0.8, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=3
    )
    # fig.add_annotation(
    #     x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s2 * 0.) / n_s),
    #     y=axis_range[1] - (axis_range[1]-axis_range[0])/14*(i+0.5),
    #     text=f"p-value={pvalue:.2f}",
    #     showarrow=False,
    #     font=dict(size=font_size, color=color),
    #     xanchor="left",
    #     bgcolor="rgba(255, 255, 255, 0.7)",
    #     row=1, col=3
    # )    
    fig.add_annotation(
        x=axis_range[0] + (axis_range[1]-axis_range[0]) * ((n_s1 + n_s3 * 0.) / 18),
        y=axis_range[1] - (axis_range[1]-axis_range[0]) / 8 * (i+0.5),
        text=f"MSE = {MSE:.2f}",
        showarrow=False,
        font=dict(size=font_size*0.8, color=color),
        xanchor="left",
        bgcolor="rgba(255, 255, 255, 0.7)",
        row=1, col=3
    )

#add diagonal line
fig.add_trace(go.Scatter(
    x=axis_range,
    y=axis_range,
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False,
    ),
    row=1, col=3
    )




#Set axis names and ranges
fig.update_xaxes(
    title_text="ln(k<sub>u,exp</sub>(s<sup>-1</sup>))",
    range=axis_range,
    dtick=7,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=3
)

fig.update_yaxes(
    title_text="ln(k<sub>u,pred</sub>(s<sup>-1</sup>))",
    range=axis_range,
    dtick=7,
    title_standoff=0,
    title_font=dict(size=font_size),
    tickfont=dict(size=font_size),
    showline=True,
    linecolor="black",
    mirror=True,
    row=1, col=3
)

################################################################################################################################################################

#Plot tytle
fig.update_layout(
    # title_text=" Predicted free energy",
    # title_x=0.5,
    # title_font=dict(size=font_size),
    width=945,
    height=400,
    showlegend=True,
    plot_bgcolor="white",
    font=dict(family="Arial", size=font_size, color='black'),
    # margin=dict(l=200, r=100, t=80, b=100),
    # row=1, col=1
)

fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.07,
    xanchor="right",
    x=1
))


# fig.write_image(f'{work_dir_path}/images/models_all_combined_test_v5_rebuttel2.png', scale=4, 
#     width=945,
#     height=400,)

fig.show()

# %% [markdown]
# ### Test consisteny of the models

# %%
common_cols
# Out:
# Index(['PDB', 'Length, aa', 'CO', 'log(P)', 'log(S)', 'log(X)',
#        'Energy, kcal/mol', 'weights', 'Length^2/3', 'log(Energy, kcal/mol)'],
#       dtype='object')

# %%
#Make a merged data frame with all structures
## Folding kinetics
# Step 1: Find common columns
common_cols = ['PDB', 'Length, aa', 'CO', 'log(P)', 'log(S)', 'log(X)']

# Step 2: Merge on those columns
merged_df_consistency = pd.concat([ACPRO_df_VA_avg[common_cols], KPro_df_VA_avg[common_cols], df_ProThermdDB_VA_avg[common_cols]], ignore_index=True)
# Out:
# PDB           167
# Length, aa    102
# CO            169
# log(P)        175
# log(S)        176
# log(X)        172
# dtype: int64

# %%
def pred_dG(spx_vec, param):
    dG = np.dot(spx_vec, param[:-1]) + param[-1]
    return dG

data = {
    "y_pred_logCT_logkf": pred_dG(merged_df_consistency[['log(P)', 'log(S)', 'log(X)']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="logCT_logkf","params"].values[0])),
    "y_pred_logCT_logku": pred_dG(merged_df_consistency[['log(P)', 'log(S)', 'log(X)']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="logCT_logku","params"].values[0])),
    "y_pred_logCT_Energy": np.exp(pred_dG(merged_df_consistency[['log(P)', 'log(S)', 'log(X)']], param = np.array(merged_regression_VA.loc[merged_regression_VA["Model"]=="logCT_logEnergy","params"].values[0]))),
}

df_lineair_regression_consistency = pd.DataFrame(data)
df_lineair_regression_consistency['PDB'] = merged_df_consistency['PDB']

# df_kinetics["T"] += 273.15
# df_kinetics["K_diff"] = (df_kinetics["ln(kf)_H2O"]-df_kinetics["ln(ku)_H2O"])
# df_kinetics["Energy, kcal/mol"] = 1.987204258640 * df_kinetics["T"] * df_kinetics["K_diff"] / 1000 #in R = 1.987204258640 cal/K/mol 

df_lineair_regression_consistency['y_pred_logCT_Energy_from_kinetics'] = 1.987204258640 * 300 * (df_lineair_regression_consistency['y_pred_logCT_logkf'] - df_lineair_regression_consistency['y_pred_logCT_logku']) / 1000
df_lineair_regression_consistency
# Out:
#      y_pred_logCT_logkf  y_pred_logCT_logku  y_pred_logCT_Energy   PDB  \
# 0              4.183818           -8.300958             6.703348  1a6n
# 1              3.229179           -8.353033             8.230654  1adw
# 2             10.789448           10.831727             2.947675  1arr
# 3              4.857314           -5.379086             5.890887  1aue
# 4              4.379939           -2.194666             4.218211  1avz
# ..                  ...                 ...                  ...   ...
# 171            2.068605           -7.860936             6.679562  4u3h
# 172            0.634145          -12.648908             9.600828  5azu
# 173            2.285490          -11.567231            10.278810  6if9
# 174            4.225332           -1.814960             4.544022  7a1h
# 175            0.409651          -17.138416            12.977718  7z5g
#
#      y_pred_logCT_Energy_from_kinetics
# 0                             7.442940
# 1                             6.904866
# 2                            -0.025205
# 3                             6.102545
# 4                             3.919525
# ..                                 ...
# 171                           5.919608
# 172                           7.918842
# 173                           8.258456
# 174                           3.600988
# 175                          10.461478
#
# [176 rows x 5 columns]

# %%
r2 = r2_score(df_lineair_regression_consistency['y_pred_logCT_Energy'], df_lineair_regression_consistency['y_pred_logCT_Energy_from_kinetics'])

fig1 = px.scatter(
    df_lineair_regression_consistency,
    x='y_pred_logCT_Energy',
    y='y_pred_logCT_Energy_from_kinetics',
    # error_x = df_lineair_regression_consistency['pred_G_calc_std'],
    # error_y=df_lineair_regression_consistency['y_pred_logPSX_energy_std'],
    
)
fig1.add_trace(go.Scatter(
    x=[-2, 17],
    y=[-2, 17],
    mode='lines',
    line=dict(color='black', width=1),
    showlegend=False
))
fig1.update_traces(
    marker_symbol='x',
    marker=dict(color='blue', size=10, opacity=0.8),
    marker_line_color="black",
    marker_line_width=1,
    error_y=dict(thickness=1.5, width=4)
)

fig1.update_xaxes(
    title_text="∆𝐺<sub>calc</sub>(kcal/mol)",
    range=[0,20], 
    title_font=dict(size=50, color='black'), 
    tickfont=dict(size=50, color='black'),
    showline=True,
    linecolor="black",
    mirror=True,
    showgrid=False
)

fig1.update_yaxes(
    title_text="∆𝐺<sub>pred</sub>(kcal/mol)",
    range=[0,17], 
    title_font=dict(size=50, color='black'),
    tickfont=dict(size=50, color='black'),
    dtick=2,
    showline=True,
    linecolor="black",
    mirror=True,
    showgrid=False
)

fig1.update_layout(
    plot_bgcolor='white',
    title_text="",
    title_x=0.5,     
    title_font=dict(size=33),
    # xaxis=dict(showgrid=False,range=[0, 4]),
    # yaxis=dict(showgrid=False, range=[0, 4]),
    showlegend=False,
    width=600,
    height=600,)

fig1.add_annotation(
    x=6.5,
    y=14,
    text=f'R² = {r2:.2f}',
    showarrow=False,
    font=dict(size=48, color='black'),
    # font=dict(size=20, color=color),
    # bgcolor="rgba(255, 255, 255, 0.7)",
    align='center'
)
fig1.write_image(f'{work_dir_path}\images\models_consistency.png', scale=4, 
    width=800,
    height=800,)
fig1.show()

# %% [markdown]
# ### Plotings

# %%
fig = make_subplots(rows=3, cols=3)

fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(P)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 1, col = 1)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(S)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 2, col = 1)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(X)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 3, col = 1)


fig.add_trace(go.Scatter(x=merged_df_VA["log(P)"], y=merged_df_VA["ln(kf)_H2O"],mode="markers"), row = 1, col = 2)
fig.add_trace(go.Scatter(x=merged_df_VA["log(S)"], y=merged_df_VA["ln(kf)_H2O"],mode="markers"), row = 2, col = 2)
fig.add_trace(go.Scatter(x=merged_df_VA["log(X)"], y=merged_df_VA["ln(kf)_H2O"],mode="markers"), row = 3, col = 2)

fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(P)"], y=KPro_df_VA_avg["ln(ku)_H2O"],mode="markers"), row = 1, col = 3)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(S)"], y=KPro_df_VA_avg["ln(ku)_H2O"],mode="markers"), row = 2, col = 3)
fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(X)"], y=KPro_df_VA_avg["ln(ku)_H2O"],mode="markers"), row = 3, col = 3)


fig.update_layout(height=800, width=800,)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[267], line 8
#       4 fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(S)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 2, col = 1)
#       5 fig.add_trace(go.Scatter(x=KPro_df_VA_avg["log(X)"], y=KPro_df_VA_avg["log(Energy, kcal/mol)"],mode="markers"), row = 3, col = 1)
# ----> 8 fig.add_trace(go.Scatter(x=merged_df_VA["log(P)"], y=merged_df_VA["ln(kf)_H2O"],mode="markers"), row = 1, col = 2)
#       9 fig.add_trace(go.Scatter(x=merged_df_VA["log(S)"], y=merged_df_VA["ln(kf)_H2O"],mode="markers"), row = 2, col = 2)
#      10 fig.add_trace(go.Scatter(x=merged_df_VA["log(X)"], y=merged_df_VA["ln(kf)_H2O"],mode="markers"), row = 3, col = 2)
#
# NameError: name 'merged_df_VA' is not defined

# %%
df.sort_values(folding_characteristic)

plt.scatter((df[folding_characteristic]), np.log(df["Length, aa"]))
# plt.scatter((df[folding_characteristic]), (df["log(X)"])/1.3)
# plt.ylim(0,1)

# %%
folding_characteristic = 'ln(kf)_H2O'

if folding_characteristic == 'ln(kf)_H2O':
    df = merged_df_VA
elif (folding_characteristic == 'ln(ku)_H2O') or ((folding_characteristic == 'log(Energy, kcal/mol)')):
    df = KPro_df_VA_avg

# Plot surface
X, Y, Z = np.mgrid[3:12:20j, 3:12:20j, 3:12:20j]

param = [-1.862, 1.794, -1.842, 16.216]	 #ln(kf) parameters
vol = X*param[0] + Y*param[1] + Z*param[2] + param[3]



# Combine both value sources to compute global min/max
all_values = np.concatenate([vol.flatten(), df[folding_characteristic].values])
cmin, cmax = all_values.min(), all_values.max()

# 3. Create volume plot
fig = go.Figure(data=go.Volume(
    x=X.flatten(), y=Y.flatten(), z=Z.flatten(),
    value=vol.flatten(),
    isomin=cmin,
    isomax=cmax,
    opacity=0.2,
    surface_count=1,
    caps=dict(x_show=True, y_show=True, z_show=True, x_fill=1),
    colorscale='RdBu',
    cmin=min(df[folding_characteristic].values),
    cmax=max(df[folding_characteristic].values),
    showscale=False  # hides duplicate colorbar
))

# 4. Add scatter trace
fig.add_trace(go.Scatter3d(
    x=df['log(P)'],
    y=df['log(S)'],
    z=df['log(X)'],
    mode='markers',
    text=df['PDB'],  # <-- Add this line for annotations
    
    marker=dict(
        size=5,
        
        color=df[folding_characteristic],
        colorscale='RdBu',
        cmin=min(df[folding_characteristic].values),
        cmax=max(df[folding_characteristic].values),
        colorbar=dict(
            title=folding_characteristic,
            # titlefont=dict(size=16),
            tickfont=dict(size=22),
            dtick=2
            ),
        showscale=False
    )
))

# 5. Layout
fig.update_layout(
    scene_camera=dict(
        up=dict(x=0, y=0, z=1),
        center=dict(x=0, y=0, z=0),
        eye=dict(x=-2.9/1.3, y=-1.5/1.3, z=1.5/1.3),
    ),
    scene=dict(
        xaxis=dict(title='log(P)', tickfont=dict(size=16), backgroundcolor="white", dtick=3,),
        yaxis=dict(title='log(S)', tickfont=dict(size=16), backgroundcolor="white", dtick=3,),
        zaxis=dict(title='log(X)', tickfont=dict(size=16), backgroundcolor="white", dtick=3,),
    ),
    plot_bgcolor="white",
    font=dict(family="Arial", size=16, color='black'),  # applies to legend, colorbar titles, etc.
    width=500,
    height=500
)


# fig.write_image(f'{work_dir_path}/images/kf_3D_cbar.png', scale=4, 
#     width=500,
#     height=500,)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 folding_characteristic = 'ln(kf)_H2O'
#       3 if folding_characteristic == 'ln(kf)_H2O':
# ----> 4     df = merged_df_VA
#       5 elif (folding_characteristic == 'ln(ku)_H2O') or ((folding_characteristic == 'log(Energy, kcal/mol)')):
#       6     df = KPro_df_VA_avg
#
# NameError: name 'merged_df_VA' is not defined

# %% [markdown]
# ## Medical test case

# %%
df = pd.read_csv(f'{work_dir_path}\pscresults_medical_validity.csv') 

df['log(P)'] = np.log(df.P)
df['log(S)'] = np.log(df.S)
df['log(X)'] = np.log(df.C)

df['dG'] = 0.07 * df['P']**0.3 * df['S']**0.09 * df['C']**0.1
df['kf'] = 9e6 * df['S']**1.8 / (df['P']**(1.9) * df['C']**(1.8))
df['ku'] = 6e15 * 1 / df['P']**(4) * df['S']**2.1 * 1 / df['C']**(4)

df['log_kf'] = np.log10(df['kf'])
df['log_ku'] = np.log10(df['ku'])

# %%
df
# Out:
#    Unnamed: 0  protid     P     S     C      I      T      L    log(P)  \
# 0           0  1CQN_B  3806  3028  1167  0.476  0.378  0.146  8.244334
# 1           1  1RIS_A  3794  3302  1160  0.460  0.400  0.141  8.241176
# 2           2  2BXJ_B  4108  3483  1187  0.468  0.397  0.135  8.320692
#
#      log(S)    log(X)        dG        kf        ku    log_kf    log_ku
# 0  8.015658  7.062192  3.461384  7.883242  0.000315  0.896705 -3.501580
# 1  8.102284  7.056175  3.483076  9.369835  0.000392  0.971732 -3.406638
# 2  8.155649  7.079184  3.592593  8.508434  0.000291  0.929850 -3.536071
